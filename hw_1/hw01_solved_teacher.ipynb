# %% [markdown]
# # Домашнее задание 1 (50 баллов)
# v4

# %% [markdown]
# В этом домашнем задании вы познакомитесь с основами NLP, научитесь обрабатывать тексты.
#
# Будет несколько теоретических вопросов, обозначенных символом 🤔.
#
# Блоки, где необходимо написать свой код, обозначены через YOUR_CODE_HERE. Код, который уже написан, менять не нужно. Блоки в разных частях задания зависят друг от друга, поэтому не вносите больших изменений, чтобы ничего не сломалось.

# %%
# !pip install gensim nltk torch tqdm seqeval
# Out:
# Requirement already satisfied: gensim in ./venv/lib/python3.10/site-packages (4.3.3)
# Requirement already satisfied: nltk in ./venv/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: torch in ./venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: tqdm in ./venv/lib/python3.10/site-packages (4.66.5)
# Requirement already satisfied: seqeval in ./venv/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in ./venv/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in ./venv/lib/python3.10/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in ./venv/lib/python3.10/site-packages (from gensim) (7.0.4)
# Requirement already satisfied: click in ./venv/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in ./venv/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.10/site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./venv/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in ./venv/lib/python3.10/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in ./venv/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in ./venv/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in ./venv/lib/python3.10/site-packages (from seqeval) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.10/site-packages (from scikit-learn>=0.21.3->seqeval) (3.5.0)
# Requirement already satisfied: wrapt in ./venv/lib/python3.10/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
from typing import List, Dict, Tuple

# %%
YOUR_CODE_HERE = None  # заглушка, здесь ничего не трогайте

# %% [markdown]
# ## Токенизация (5 баллов)

# %% [markdown]
# Токенизация - это процесс преобразования текста в набор токенов.
# Наивная реализация разбивает текст по пробелам. Более умные реализации учитывают пунктуацию.
#
# Научимся работать с токенизацией NLTK, где уже реализована работа с пунктуацией.
#
# https://www.nltk.org/

# %%
import nltk

# https://www.nltk.org/nltk_data/
# nltk.download("punkt")
# nltk.download('punkt_tab')

# %%
def tokenize(text: str, language: str = "english", lower: bool = False) -> List[str]:
    # YOUR_CODE_HERE
    if lower:
        text = text.lower()
    return nltk.word_tokenize(text, language=language)

assert tokenize("") == []
assert tokenize("Hello, world!") == ["Hello", ",", "world", "!"]
assert tokenize("EU rejects German call to boycott British lamb.") == ["EU", "rejects", "German", "call", "to", "boycott", "British", "lamb", "."]

# %%
def split_sentences(text: str, language: str = "english", lower: bool = False) -> List[str]:
    # YOUR_CODE_HERE
    if lower:
        text = text.lower()
    return nltk.sent_tokenize(text, language=language)

assert split_sentences("") == []
assert split_sentences("Hello, world!") == ["Hello, world!"]
assert split_sentences("Hello, world! I love Python!") == ["Hello, world!", "I love Python!"]

# %% [markdown]
# ## Векторизация (5 баллов)

# %% [markdown]
# Чтобы работать с текстами, нужно преобразовать токены (слова) в векторы.
# Для этого сначала необходимо составить словарь и сопоставить каждому слову уникальный индекс.
# В образовательных целях реализуем этот словарь с нуля.

# %%
from collections import defaultdict, Counter

# %%
class Vocabulary:
    def __init__(self, texts: List[str], language: str = "english", min_count: int = 1, lower: bool = False):
        """
        Создание словаря.

        :param texts: коллекция текстов
        :param language: язык текстов
        :param min_count: минимальная частота слова для попадания в словарь
        """
        self.language = language
        self.lower = lower
        self.min_count = min_count
        self.word2idx = {"<PAD>": 0, "<SOS>": 1, "<EOS>": 2, "<UNK>": 3}
        self.idx2word = {0: "<PAD>", 1: "<SOS>", 2: "<EOS>", 3: "<UNK>"}
        self.word2count = Counter()
        self._build_vocabulary(texts)

    def _build_vocabulary(self, texts: List[str]):
        for text in texts:
            # YOUR_CODE_HERE
            tokenized_text = tokenize(text, self.language, self.lower)
            for word in tokenized_text:
                self.word2count[word] += 1

        for word, count in self.word2count.items():
            # YOUR_CODE_HERE
            if count >= self.min_count:
                idx = len(self.word2idx)
                self.word2idx[word] = idx
                self.idx2word[idx] = word

    def encode_word(self, text: str) -> int:
        if self.lower:
            text = text.lower()
        return self.word2idx.get(text, self.word2idx["<UNK>"])

    def encode(self, text: str) -> List[int]:
        """
        Кодирование текста в набор индексов.

        :param text: текст
        :return: набор индексов токенов
        """
        # YOUR_CODE_HERE
        return [self.encode_word(word) for word in tokenize(text, self.language, self.lower)]

    def decode(self, input_ids: List[int]) -> str:
        """
        Декодирование набора индексов в текст.

        :param input_ids: набор индексов токенов
        :return: текст
        """
        return " ".join([self.idx2word[idx] for idx in input_ids if idx != self.word2idx["<PAD>"]])

    def __len__(self):
        return len(self.word2idx)

    def __contains__(self, item):
        return item in self.word2idx

    def __iter__(self):
        return iter(self.word2idx)

    def __str__(self):
        return str(self.word2idx)

# %%
vocab = Vocabulary(["Hello, world!", "I love Python!"], min_count=1, lower=True)
encoded = vocab.encode("Hello, Python! I love you")
assert vocab.decode(encoded) == "hello , python ! i love <UNK>"

# %% [markdown]
# ## $n$-граммные языковые модели (10 баллов)

# %% [markdown]
# Напишем собственную $n$-граммную модель.

# %%
class NGramLanguageModel:
    def __init__(self, n: int, vocabulary: Vocabulary, texts: List[str]):
        """
        Создание n-граммной языковой модели.

        :param n: порядок n-грамм
        :param vocabulary: словарь
        """
        assert n >= 2
        self.n = n
        self.vocabulary = vocabulary
        self.frequencies = defaultdict(lambda: Counter())  # частота n-грамм
        self.frequencies_of_prefixes = Counter()  # сумма частот n-грамм для префиксов
        self._build_model(texts)

    def _build_model(self, texts: List[str]):
        for text in texts:
            tokens = self.vocabulary.encode(text) + [self.vocabulary.word2idx["<EOS>"]]
            for i in range(len(tokens)):
                # YOUR_CODE_HERE
                if not i:
                    prefix = []
                else:
                    prefix = tokens[max(0, i - self.n + 1):i]
                prefix = tuple(prefix)
                current_token = tokens[i]
                self.frequencies[prefix][current_token] += 1
                self.frequencies_of_prefixes[prefix] += 1

    def _get_probability(self, prefix: List[int], token: int) -> float:
        # YOUR_CODE_HERE
        prefix = tuple(prefix)
        return self.frequencies[prefix][token] / self.frequencies_of_prefixes.get(prefix, 1)

    def generate_next_token(self, prefix: List[int]) -> int:
        """
        Генерация следующего токена по префиксу.

        :param prefix: префикс
        :return: следующий токен
        """
        # YOUR_CODE_HERE
        prefix = tuple(prefix)
        distribution = self.frequencies[prefix]
        if not distribution:
            return self.vocabulary.word2idx["<UNK>"]
        next_token, _ = distribution.most_common(1)[0]
        return next_token

    def autocomplete(self, text: str, max_len: int = 32) -> str:
        """
        Автоматическое завершение текста.

        :param text: текст
        :param max_len: максимальная длина текста
        :return: завершенный текст
        """
        tokens = self.vocabulary.encode(text)
        assert tokens

        # YOUR_CODE_HERE
        while len(tokens) < max_len:
            i = len(tokens)
            if not i:
                prefix = []
            else:
                prefix = tokens[max(0, i - self.n + 1):i]
            current_token = self.generate_next_token(prefix)
            tokens.append(current_token)
            if current_token == self.vocabulary.word2idx["<EOS>"]:
                break

        return self.vocabulary.decode(tokens)

# %%
texts = ["Hello, world!", "I love Python!", "Hello, Python"]
vocab = Vocabulary(["Hello, world!", "I love Python!"], min_count=1, lower=True)
print(vocab)
ngram_lm = NGramLanguageModel(2, vocab, texts)
assert ngram_lm.autocomplete("Hello, Python", max_len=10) == "hello , python ! <EOS>"
# Out:
# {'<PAD>': 0, '<SOS>': 1, '<EOS>': 2, '<UNK>': 3, 'hello': 4, ',': 5, 'world': 6, '!': 7, 'i': 8, 'love': 9, 'python': 10}

# %% [markdown]
# 🤔 Можно ли использовать $n$-граммную языковую модель, когда длина префикса меньше, чем $n-1$? Если да, то как? Если нет, то почему?

# %% [markdown]
# Да, можно. Добавим в начало каждого текста $n - 1$ токен <SOS>. Это эквивалентно тому, чтобы в коде использовать префикс меньшей длины (если длина префикса меньше $n - 1$, вы всегда можем мысленно поставить нужное число токенов <SOS> в начале).

# %% [markdown]
# 🤔 Что произойдет, если в $n$-граммной языковой модели взять достаточно большое $n$?

# %% [markdown]
# Матрица подсчетов будет очень разреженной, понадобится много данных, чтобы собрать статистики. Это связано с проклятием размерности.

# %% [markdown]
# ## Word2Vec (5 баллов)

# %% [markdown]
# Познакомимся с моделью Word2Vec. Для русского языка есть обученные модели.
# https://rusvectores.org/ru/models/
#
# Модели для английского языка: https://github.com/piskvorky/gensim-data
#
# Научимся доставать эмбеддинги слов из обученных моделей.

# %%
from gensim.models import KeyedVectors
import gensim.downloader as api

# %%
info = api.info()  # show info about available models/datasets

# %%
info
# Out:
# {'corpora': {'semeval-2016-2017-task3-subtaskBC': {'num_records': -1,
#    'record_format': 'dict',
#    'file_size': 6344358,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/semeval-2016-2017-task3-subtaskB-eng/__init__.py',
#    'license': 'All files released for the task are free for general research use',
#    'fields': {'2016-train': ['...'],
#     '2016-dev': ['...'],
#     '2017-test': ['...'],
#     '2016-test': ['...']},
#    'description': 'SemEval 2016 / 2017 Task 3 Subtask B and C datasets contain train+development (317 original questions, 3,169 related questions, and 31,690 comments), and test datasets in English. The description of the tasks and the collected data is given in sections 3 and 4.1 of the task paper http://alt.qcri.org/semeval2016/task3/data/uploads/semeval2016-task3-report.pdf linked in section “Papers” of https://github.com/RaRe-Technologies/gensim-data/issues/18.',
#    'checksum': '701ea67acd82e75f95e1d8e62fb0ad29',
#    'file_name': 'semeval-2016-2017-task3-subtaskBC.gz',
#    'read_more': ['http://alt.qcri.org/semeval2017/task3/',
#     'http://alt.qcri.org/semeval2017/task3/data/uploads/semeval2017-task3.pdf',
#     'https://github.com/RaRe-Technologies/gensim-data/issues/18',
#     'https://github.com/Witiko/semeval-2016_2017-task3-subtaskB-english'],
#    'parts': 1},
#   'semeval-2016-2017-task3-subtaskA-unannotated': {'num_records': 189941,
#    'record_format': 'dict',
#    'file_size': 234373151,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/semeval-2016-2017-task3-subtaskA-unannotated-eng/__init__.py',
#    'license': 'These datasets are free for general research use.',
#    'fields': {'THREAD_SEQUENCE': '',
#     'RelQuestion': {'RELQ_CATEGORY': 'question category, according to the Qatar Living taxonomy',
#      'RELQ_DATE': 'date of posting',
#      'RELQ_ID': 'question indentifier',
#      'RELQ_USERID': 'identifier of the user asking the question',
#      'RELQ_USERNAME': 'name of the user asking the question',
#      'RelQBody': 'body of question',
#      'RelQSubject': 'subject of question'},
#     'RelComments': [{'RelCText': 'text of answer',
#       'RELC_USERID': 'identifier of the user posting the comment',
#       'RELC_ID': 'comment identifier',
#       'RELC_USERNAME': 'name of the user posting the comment',
#       'RELC_DATE': 'date of posting'}]},
#    'description': 'SemEval 2016 / 2017 Task 3 Subtask A unannotated dataset contains 189,941 questions and 1,894,456 comments in English collected from the Community Question Answering (CQA) web forum of Qatar Living. These can be used as a corpus for language modelling.',
#    'checksum': '2de0e2f2c4f91c66ae4fcf58d50ba816',
#    'file_name': 'semeval-2016-2017-task3-subtaskA-unannotated.gz',
#    'read_more': ['http://alt.qcri.org/semeval2016/task3/',
#     'http://alt.qcri.org/semeval2016/task3/data/uploads/semeval2016-task3-report.pdf',
#     'https://github.com/RaRe-Technologies/gensim-data/issues/18',
#     'https://github.com/Witiko/semeval-2016_2017-task3-subtaskA-unannotated-english'],
#    'parts': 1},
#   'patent-2017': {'num_records': 353197,
#    'record_format': 'dict',
#    'file_size': 3087262469,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/patent-2017/__init__.py',
#    'license': 'not found',
#    'description': "Patent Grant Full Text. Contains the full text including tables, sequence data and 'in-line' mathematical expressions of each patent grant issued in 2017.",
#    'checksum-0': '818501f0b9af62d3b88294d86d509f8f',
#    'checksum-1': '66c05635c1d3c7a19b4a335829d09ffa',
#    'file_name': 'patent-2017.gz',
#    'read_more': ['http://patents.reedtech.com/pgrbft.php'],
#    'parts': 2},
#   'quora-duplicate-questions': {'num_records': 404290,
#    'record_format': 'dict',
#    'file_size': 21684784,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/quora-duplicate-questions/__init__.py',
#    'license': 'probably https://www.quora.com/about/tos',
#    'fields': {'question1': 'the full text of each question',
#     'question2': 'the full text of each question',
#     'qid1': 'unique ids of each question',
#     'qid2': 'unique ids of each question',
#     'id': 'the id of a training set question pair',
#     'is_duplicate': 'the target variable, set to 1 if question1 and question2 have essentially the same meaning, and 0 otherwise'},
#    'description': 'Over 400,000 lines of potential question duplicate pairs. Each line contains IDs for each question in the pair, the full text for each question, and a binary value that indicates whether the line contains a duplicate pair or not.',
#    'checksum': 'd7cfa7fbc6e2ec71ab74c495586c6365',
#    'file_name': 'quora-duplicate-questions.gz',
#    'read_more': ['https://data.quora.com/First-Quora-Dataset-Release-Question-Pairs'],
#    'parts': 1},
#   'wiki-english-20171001': {'num_records': 4924894,
#    'record_format': 'dict',
#    'file_size': 6516051717,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/wiki-english-20171001/__init__.py',
#    'license': 'https://dumps.wikimedia.org/legal.html',
#    'fields': {'section_texts': 'list of body of sections',
#     'section_titles': 'list of titles of sections',
#     'title': 'Title of wiki article'},
#    'description': 'Extracted Wikipedia dump from October 2017. Produced by `python -m gensim.scripts.segment_wiki -f enwiki-20171001-pages-articles.xml.bz2 -o wiki-en.gz`',
#    'checksum-0': 'a7d7d7fd41ea7e2d7fa32ec1bb640d71',
#    'checksum-1': 'b2683e3356ffbca3b6c2dca6e9801f9f',
#    'checksum-2': 'c5cde2a9ae77b3c4ebce804f6df542c2',
#    'checksum-3': '00b71144ed5e3aeeb885de84f7452b81',
#    'file_name': 'wiki-english-20171001.gz',
#    'read_more': ['https://dumps.wikimedia.org/enwiki/20171001/'],
#    'parts': 4},
#   'text8': {'num_records': 1701,
#    'record_format': 'list of str (tokens)',
#    'file_size': 33182058,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/text8/__init__.py',
#    'license': 'not found',
#    'description': 'First 100,000,000 bytes of plain text from Wikipedia. Used for testing purposes; see wiki-english-* for proper full Wikipedia datasets.',
#    'checksum': '68799af40b6bda07dfa47a32612e5364',
#    'file_name': 'text8.gz',
#    'read_more': ['http://mattmahoney.net/dc/textdata.html'],
#    'parts': 1},
#   'fake-news': {'num_records': 12999,
#    'record_format': 'dict',
#    'file_size': 20102776,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/fake-news/__init__.py',
#    'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#    'fields': {'crawled': 'date the story was archived',
#     'ord_in_thread': '',
#     'published': 'date published',
#     'participants_count': 'number of participants',
#     'shares': 'number of Facebook shares',
#     'replies_count': 'number of replies',
#     'main_img_url': 'image from story',
#     'spam_score': 'data from webhose.io',
#     'uuid': 'unique identifier',
#     'language': 'data from webhose.io',
#     'title': 'title of story',
#     'country': 'data from webhose.io',
#     'domain_rank': 'data from webhose.io',
#     'author': 'author of story',
#     'comments': 'number of Facebook comments',
#     'site_url': 'site URL from BS detector',
#     'text': 'text of story',
#     'thread_title': '',
#     'type': 'type of website (label from BS detector)',
#     'likes': 'number of Facebook likes'},
#    'description': "News dataset, contains text and metadata from 244 websites and represents 12,999 posts in total from a specific window of 30 days. The data was pulled using the webhose.io API, and because it's coming from their crawler, not all websites identified by their BS Detector are present in this dataset. Data sources that were missing a label were simply assigned a label of 'bs'. There are (ostensibly) no genuine, reliable, or trustworthy news sources represented in this dataset (so far), so don't trust anything you read.",
#    'checksum': '5e64e942df13219465927f92dcefd5fe',
#    'file_name': 'fake-news.gz',
#    'read_more': ['https://www.kaggle.com/mrisdal/fake-news'],
#    'parts': 1},
#   '20-newsgroups': {'num_records': 18846,
#    'record_format': 'dict',
#    'file_size': 14483581,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/20-newsgroups/__init__.py',
#    'license': 'not found',
#    'fields': {'topic': 'name of topic (20 variant of possible values)',
#     'set': "marker of original split (possible values 'train' and 'test')",
#     'data': '',
#     'id': 'original id inferred from folder name'},
#    'description': 'The notorious collection of approximately 20,000 newsgroup posts, partitioned (nearly) evenly across 20 different newsgroups.',
#    'checksum': 'c92fd4f6640a86d5ba89eaad818a9891',
#    'file_name': '20-newsgroups.gz',
#    'read_more': ['http://qwone.com/~jason/20Newsgroups/'],
#    'parts': 1},
#   '__testing_matrix-synopsis': {'description': '[THIS IS ONLY FOR TESTING] Synopsis of the movie matrix.',
#    'checksum': '1767ac93a089b43899d54944b07d9dc5',
#    'file_name': '__testing_matrix-synopsis.gz',
#    'read_more': ['http://www.imdb.com/title/tt0133093/plotsummary?ref_=ttpl_pl_syn#synopsis'],
#    'parts': 1},
#   '__testing_multipart-matrix-synopsis': {'description': '[THIS IS ONLY FOR TESTING] Synopsis of the movie matrix.',
#    'checksum-0': 'c8b0c7d8cf562b1b632c262a173ac338',
#    'checksum-1': '5ff7fc6818e9a5d9bc1cf12c35ed8b96',
#    'checksum-2': '966db9d274d125beaac7987202076cba',
#    'file_name': '__testing_multipart-matrix-synopsis.gz',
#    'read_more': ['http://www.imdb.com/title/tt0133093/plotsummary?ref_=ttpl_pl_syn#synopsis'],
#    'parts': 3}},
#  'models': {'fasttext-wiki-news-subwords-300': {'num_records': 999999,
#    'file_size': 1005007116,
#    'base_dataset': 'Wikipedia 2017, UMBC webbase corpus and statmt.org news dataset (16B tokens)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/fasttext-wiki-news-subwords-300/__init__.py',
#    'license': 'https://creativecommons.org/licenses/by-sa/3.0/',
#    'parameters': {'dimension': 300},
#    'description': '1 million word vectors trained on Wikipedia 2017, UMBC webbase corpus and statmt.org news dataset (16B tokens).',
#    'read_more': ['https://fasttext.cc/docs/en/english-vectors.html',
#     'https://arxiv.org/abs/1712.09405',
#     'https://arxiv.org/abs/1607.01759'],
#    'checksum': 'de2bb3a20c46ce65c9c131e1ad9a77af',
#    'file_name': 'fasttext-wiki-news-subwords-300.gz',
#    'parts': 1},
#   'conceptnet-numberbatch-17-06-300': {'num_records': 1917247,
#    'file_size': 1225497562,
#    'base_dataset': 'ConceptNet, word2vec, GloVe, and OpenSubtitles 2016',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/conceptnet-numberbatch-17-06-300/__init__.py',
#    'license': 'https://github.com/commonsense/conceptnet-numberbatch/blob/master/LICENSE.txt',
#    'parameters': {'dimension': 300},
#    'description': 'ConceptNet Numberbatch consists of state-of-the-art semantic vectors (also known as word embeddings) that can be used directly as a representation of word meanings or as a starting point for further machine learning. ConceptNet Numberbatch is part of the ConceptNet open data project. ConceptNet provides lots of ways to compute with word meanings, one of which is word embeddings. ConceptNet Numberbatch is a snapshot of just the word embeddings. It is built using an ensemble that combines data from ConceptNet, word2vec, GloVe, and OpenSubtitles 2016, using a variation on retrofitting.',
#    'read_more': ['http://aaai.org/ocs/index.php/AAAI/AAAI17/paper/view/14972',
#     'https://github.com/commonsense/conceptnet-numberbatch',
#     'http://conceptnet.io/'],
#    'checksum': 'fd642d457adcd0ea94da0cd21b150847',
#    'file_name': 'conceptnet-numberbatch-17-06-300.gz',
#    'parts': 1},
#   'word2vec-ruscorpora-300': {'num_records': 184973,
#    'file_size': 208427381,
#    'base_dataset': 'Russian National Corpus (about 250M words)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/word2vec-ruscorpora-300/__init__.py',
#    'license': 'https://creativecommons.org/licenses/by/4.0/deed.en',
#    'parameters': {'dimension': 300, 'window_size': 10},
#    'description': 'Word2vec Continuous Skipgram vectors trained on full Russian National Corpus (about 250M words). The model contains 185K words.',
#    'preprocessing': 'The corpus was lemmatized and tagged with Universal PoS',
#    'read_more': ['https://www.academia.edu/24306935/WebVectors_a_Toolkit_for_Building_Web_Interfaces_for_Vector_Semantic_Models',
#     'http://rusvectores.org/en/',
#     'https://github.com/RaRe-Technologies/gensim-data/issues/3'],
#    'checksum': '9bdebdc8ae6d17d20839dd9b5af10bc4',
#    'file_name': 'word2vec-ruscorpora-300.gz',
#    'parts': 1},
#   'word2vec-google-news-300': {'num_records': 3000000,
#    'file_size': 1743563840,
#    'base_dataset': 'Google News (about 100 billion words)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/word2vec-google-news-300/__init__.py',
#    'license': 'not found',
#    'parameters': {'dimension': 300},
#    'description': "Pre-trained vectors trained on a part of the Google News dataset (about 100 billion words). The model contains 300-dimensional vectors for 3 million words and phrases. The phrases were obtained using a simple data-driven approach described in 'Distributed Representations of Words and Phrases and their Compositionality' (https://code.google.com/archive/p/word2vec/).",
#    'read_more': ['https://code.google.com/archive/p/word2vec/',
#     'https://arxiv.org/abs/1301.3781',
#     'https://arxiv.org/abs/1310.4546',
#     'https://www.microsoft.com/en-us/research/publication/linguistic-regularities-in-continuous-space-word-representations/?from=http%3A%2F%2Fresearch.microsoft.com%2Fpubs%2F189726%2Frvecs.pdf'],
#    'checksum': 'a5e5354d40acb95f9ec66d5977d140ef',
#    'file_name': 'word2vec-google-news-300.gz',
#    'parts': 1},
#   'glove-wiki-gigaword-50': {'num_records': 400000,
#    'file_size': 69182535,
#    'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-50/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 50},
#    'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword, 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-50.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': 'c289bc5d7f2f02c6dc9f2f9b67641813',
#    'file_name': 'glove-wiki-gigaword-50.gz',
#    'parts': 1},
#   'glove-wiki-gigaword-100': {'num_records': 400000,
#    'file_size': 134300434,
#    'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-100/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 100},
#    'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-100.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': '40ec481866001177b8cd4cb0df92924f',
#    'file_name': 'glove-wiki-gigaword-100.gz',
#    'parts': 1},
#   'glove-wiki-gigaword-200': {'num_records': 400000,
#    'file_size': 264336934,
#    'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-200/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 200},
#    'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword, 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-200.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': '59652db361b7a87ee73834a6c391dfc1',
#    'file_name': 'glove-wiki-gigaword-200.gz',
#    'parts': 1},
#   'glove-wiki-gigaword-300': {'num_records': 400000,
#    'file_size': 394362229,
#    'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-300/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 300},
#    'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword, 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-300.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': '29e9329ac2241937d55b852e8284e89b',
#    'file_name': 'glove-wiki-gigaword-300.gz',
#    'parts': 1},
#   'glove-twitter-25': {'num_records': 1193514,
#    'file_size': 109885004,
#    'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-25/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 25},
#    'description': 'Pre-trained vectors based on 2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-25.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': '50db0211d7e7a2dcd362c6b774762793',
#    'file_name': 'glove-twitter-25.gz',
#    'parts': 1},
#   'glove-twitter-50': {'num_records': 1193514,
#    'file_size': 209216938,
#    'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-50/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 50},
#    'description': 'Pre-trained vectors based on 2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/)',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-50.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': 'c168f18641f8c8a00fe30984c4799b2b',
#    'file_name': 'glove-twitter-50.gz',
#    'parts': 1},
#   'glove-twitter-100': {'num_records': 1193514,
#    'file_size': 405932991,
#    'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-100/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 100},
#    'description': 'Pre-trained vectors based on  2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/)',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-100.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': 'b04f7bed38756d64cf55b58ce7e97b15',
#    'file_name': 'glove-twitter-100.gz',
#    'parts': 1},
#   'glove-twitter-200': {'num_records': 1193514,
#    'file_size': 795373100,
#    'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-200/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 200},
#    'description': 'Pre-trained vectors based on 2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-200.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': 'e52e8392d1860b95d5308a525817d8f9',
#    'file_name': 'glove-twitter-200.gz',
#    'parts': 1},
#   '__testing_word2vec-matrix-synopsis': {'description': '[THIS IS ONLY FOR TESTING] Word vecrors of the movie matrix.',
#    'parameters': {'dimensions': 50},
#    'preprocessing': 'Converted to w2v using a preprocessed corpus. Converted to w2v format with `python3.5 -m gensim.models.word2vec -train <input_filename> -iter 50 -output <output_filename>`.',
#    'read_more': [],
#    'checksum': '534dcb8b56a360977a269b7bfc62d124',
#    'file_name': '__testing_word2vec-matrix-synopsis.gz',
#    'parts': 1}}}

# %%
# вы можете выбрать любую модель из gensim, например fasstext
# w2v_model = api.load("glove-twitter-25")
w2v_model = KeyedVectors.load_word2vec_format('data/gensim/glove-twitter-25.gz')

# %%
print(w2v_model["potato"])
# Out:
# [-0.41654   -0.56071    0.72333    1.0435     0.0098203  0.46871
#   0.93296   -1.2629     0.074417  -0.061837   0.9251    -0.25308
#  -2.183     -1.3639    -0.30995   -0.98977    1.6252    -1.0291
#  -0.047819   0.64689    0.062647   0.54722   -0.36114    0.15535
#   1.0872   ]

# %%
print(w2v_model.most_similar(positive=["potato", "burger"]))
# Out:
# [('chicken', 0.9732475280761719), ('cheese', 0.9607888460159302), ('waffle', 0.9480125308036804), ('salad', 0.943723201751709), ('fried', 0.9288325905799866), ('steak', 0.926487147808075), ('pepper', 0.9241527915000916), ('fries', 0.9237129092216492), ('soup', 0.9213549494743347), ('spicy', 0.9193410873413086)]

# %%
print(w2v_model.most_similar(positive=["potato", "tomato"]))
# Out:
# [('pepper', 0.9478217959403992), ('garlic', 0.9469695091247559), ('avocado', 0.9457836151123047), ('spicy', 0.9435321092605591), ('chicken', 0.9432903528213501), ('beans', 0.9419039487838745), ('onion', 0.9399765729904175), ('fried', 0.9379871487617493), ('cheese', 0.9373629689216614), ('salad', 0.9371017217636108)]

# %% [markdown]
# Реализуйте самостояительно методы $3CosAdd$ и $3CosMul$:
#
# $b^* = \arg \max_{w \in W} \cos (w, a^* - a + b)$
#
# $b^* = \arg \max_{w \in W} \frac{\cos(w, b) \times \cos(w, a^*)}{\cos(w, a)}$

# %%
import numpy as np

# %%
def three_cos_add(a: str, b: str, a_star: str) -> str:
    # YOUR_CODE_HERE
    matrix = np.array(w2v_model.vectors)
    matrix /= (matrix ** 2).sum(axis=1, keepdims=True) ** 0.5
    
    rhs_vector = np.array(w2v_model[a_star] - w2v_model[a] + w2v_model[b])
    rhs_vector /= (rhs_vector ** 2).sum() ** 0.5

    similarities = matrix @ rhs_vector.reshape(-1, 1)
    b_star_index = similarities.reshape(-1).argmax()
    b_star = w2v_model.index_to_key[b_star_index]
    return b_star

# %%
def three_cos_mul(a: str, b: str, a_star: str) -> str:
    # YOUR_CODE_HERE
    matrix = np.array(w2v_model.vectors)
    matrix /= (matrix ** 2).sum(axis=1, keepdims=True) ** 0.5
    
    a_vector = np.array(w2v_model[a])
    a_vector /= (a_vector ** 2).sum() ** 0.5
    
    a_star_vector = np.array(w2v_model[a_star])
    a_star_vector /= (a_star_vector ** 2).sum() ** 0.5

    b_vector = np.array(w2v_model[b])
    b_vector /= (b_vector ** 2).sum() ** 0.5
    
    cosines_w_a, cosines_w_a_star, cosines_w_b = (matrix @ np.stack([a_vector, a_star_vector, b_vector], 1)).T
    similarities = cosines_w_b * cosines_w_a_star / cosines_w_a
    b_star_index = similarities.reshape(-1).argmax()
    b_star = w2v_model.index_to_key[b_star_index]
    return b_star

# %%
three_cos_add("man", "woman", "king")
# Out:
# 'meets'

# %%
# %%timeit -r 10 -n 1
three_cos_add("man", "woman", "king")
# Out:
# 115 ms ± 4.09 ms per loop (mean ± std. dev. of 10 runs, 1 loop each)

# %%
three_cos_mul("man", "woman", "king")
# Out:
# 'pinkett-smith'

# %%
# %%timeit -r 10 -n 1
three_cos_mul("man", "woman", "king")
# Out:
# 123 ms ± 5.32 ms per loop (mean ± std. dev. of 10 runs, 1 loop each)

# %% [markdown]
# ## Эмбеддинги и RNN в PyTorch (5 баллов)

# %% [markdown]
# Для использования эмбеддингов в нейросетях на torch нужен специальный слой Embedding.
# Посмотрим, как он работает.

# %%
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

# %%
emd_dim = 6
embedding_layer = nn.Embedding(len(vocab), emd_dim)

batch_size = 2
seq_len = 5

input_ids = torch.tensor([[1, 2, 3, 4, 5], [1, 5, 6, 0, 0]]).long()
key_padding_mask = input_ids > 0

assert input_ids.shape == (batch_size, seq_len)

embeddings = embedding_layer(input_ids)
print(embeddings)
print(embeddings.shape)
assert embeddings.shape == (batch_size, seq_len, emd_dim)
# Out:
# tensor([[[ 1.0438,  1.3737, -1.1807, -0.8451,  0.4941, -0.1848],
#          [ 0.1735, -1.2994, -0.1904, -0.6496, -0.8584,  1.7601],
#          [ 0.9538,  0.9900, -0.5806,  1.5981,  1.2591,  0.6463],
#          [ 0.6117, -1.3136,  0.0854,  0.0716,  0.2873, -0.0266],
#          [-0.2610, -1.2148,  1.1984,  0.8749, -1.8212,  0.8222]],
#
#         [[ 1.0438,  1.3737, -1.1807, -0.8451,  0.4941, -0.1848],
#          [-0.2610, -1.2148,  1.1984,  0.8749, -1.8212,  0.8222],
#          [-0.6442, -1.1098, -0.5715,  1.3968,  0.2889, -0.9777],
#          [ 1.2083,  1.5805, -0.0321, -1.4654,  1.0254,  1.9414],
#          [ 1.2083,  1.5805, -0.0321, -1.4654,  1.0254,  1.9414]]],
#        grad_fn=<EmbeddingBackward0>)
# torch.Size([2, 5, 6])

# %% [markdown]
# В качестве RNN возьмем двунаправленную LSTM.

# %%
hidden_size = 7
n_layers = 3

rnn = nn.LSTM(
    emd_dim, hidden_size,
    num_layers=n_layers,
    bidirectional=True,
    batch_first=True,
    dropout=0.2,
)

# Прочитайте туториал по паддингу в RNN
# https://www.geeksforgeeks.org/how-do-you-handle-sequence-padding-and-packing-in-pytorch-for-rnns/

packed_input = pack_padded_sequence(
    embeddings,
    key_padding_mask.sum(1).cpu().numpy(),
    batch_first=True
)
rnn_outputs, (h, c) = rnn(packed_input)
rnn_outputs, input_sizes = pad_packed_sequence(
    rnn_outputs, batch_first=True
)
assert rnn_outputs.shape == (batch_size, seq_len, hidden_size * 2)

# %% [markdown]
# 🤔 Почему для рекуррентных сетей нужен специальный паддинг?

# %% [markdown]
# Для однонаправленных не очень-то и нужен --- монжо западдить обычным методом и проигнорировать выходы сети на месте паддинга. Проблема возникает, когда начинаем использовать двунаправленные сети. Последовательности выровнены только по левому краю, поэтому и трубуется специальная "упаковка".

# %% [markdown]
# ## Извлечение именованных сущностей (NER) (20 баллов)

# %% [markdown]
# Теперь мы готовы к тому, чтобы создать полную сеть для решения задачи распознавания именованных сущностей через потокенную классификацию.

# %%
from torch.utils.data import DataLoader
from tqdm.auto import tqdm

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ### Архитектура и подготовка обучения (10 баллов)

# %%
class TokenClassificationModel(nn.Module):
    def __init__(self, vocab_size: int, embedding_dim: int, hidden_size: int, n_layers: int, n_classes: int):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.LSTM(
            embedding_dim, hidden_size,
            num_layers=n_layers,
            dropout=0.2,
            bidirectional=True,
            batch_first=True,
        )
        self.n_classes = n_classes
        self.fc = nn.Linear(hidden_size * 2, n_classes)
        self.loss_fn = nn.CrossEntropyLoss(ignore_index=-100, reduction="none")

    def forward(self, x: torch.Tensor, mask: torch.Tensor):
        # YOUR_CODE_HERE
        embeddings = self.embedding(x)
        packed_input = pack_padded_sequence(
            embeddings,
            mask.sum(1).cpu().numpy(),
            enforce_sorted=False,
            batch_first=True,
        )
        rnn_outputs, (h, c) = self.rnn(packed_input)
        rnn_outputs, input_sizes = pad_packed_sequence(
            rnn_outputs,
            batch_first=True,
        )
        return self.fc(rnn_outputs)

    def training_step(self, batch):
        input_ids = batch["input_ids"]
        mask = batch["mask"]
        labels = batch["labels"]

        # YOUR_CODE_HERE
        logits = self.forward(input_ids, mask)
        loss = self.loss_fn(logits.reshape(-1, self.n_classes), labels.reshape(-1))
        loss = loss.sum() / mask.sum()

        return loss

    def validation_step(self, batch):
        # YOUR_CODE_HERE
        input_ids = batch["input_ids"]
        mask = batch["mask"]
        labels = batch["labels"]
        
        logits = self.forward(input_ids, mask)
        loss = self.loss_fn(logits.reshape(-1, self.n_classes), labels.reshape(-1))
        loss = loss.sum() / mask.sum()

        return loss

    def configure_optimizers(self):
        # YOUR_CODE_HERE
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-2)
        return optimizer

# %%
def collate_fn(data):
    input_ids = []
    masks = []
    labels = []
    max_len = 0
    for sample in data:
        input_ids.append([vocab.encode_word(token) for token in sample["tokens"]])
        labels.append([label2idx[y] for y in sample["labels"]])
        l = len(input_ids[-1])
        masks.append([1] * l)
        max_len = max(max_len, l)
        
    # YOUR_CODE_HERE
    for i in range(len(input_ids)):
        l = len(input_ids[i])
        input_ids[i].extend([0] * (max_len - l))
        labels[i].extend([-100] * (max_len - l))  # значение, по которому не будет считаться лосс. Указывается как ignore_index
        masks[i].extend([0] * (max_len - l))
    batch = {
        "input_ids": torch.tensor(input_ids, dtype=torch.int64, device=device),
        "mask": torch.tensor(masks, dtype=torch.bool, device=device),
        "labels": torch.tensor(labels, dtype=torch.long, device=device)
    }
    return batch

# %%
idx2label = ["O", "B-MISC", "I-MISC", "B-PER", "I-PER", "B-ORG", "I-ORG", "B-LOC", "I-LOC"]
label2idx = {label: i for i, label in enumerate(idx2label)}

# %%
def read_data(path: str) -> List[Dict[str, List[str]]]:
    samples = []
    with open(path) as f:
        sentences = f.read().split("\n\n")
    for sentence in sentences:
        if "-DOCSTART-" in sentence:
            continue
        tokens = []
        labels = []
        for line in sentence.strip().split("\n"):
            if not line:
                continue
            line = line.split()
            tokens.append(line[0])
            labels.append(line[-1])
        if not tokens:
            continue
        samples.append({"tokens": tokens, "labels": labels})
    return samples

# %%
train_data = read_data("data/conll2003/train.txt")
val_data = read_data("data/conll2003/valid.txt")
test_data = read_data("data/conll2003/test.txt")
print(len(train_data), len(val_data), len(test_data))
# Out:
# 14041 3250 3453

# %% [markdown]
# Прочитайте про схемы тегирования в NER: https://en.wikipedia.org/wiki/Inside–outside–beginning_(tagging)

# %% [markdown]
# 🤔 Какая схема тегирования используется в этом датасете?

# %% [markdown]
# IOB2.

# %%
N_EPOCHS = 10
BATCH_SIZE = 32

# %%
train_dl = DataLoader(train_data, collate_fn=collate_fn, batch_size=BATCH_SIZE, shuffle=True)
val_dl = DataLoader(val_data, collate_fn=collate_fn, batch_size=BATCH_SIZE, shuffle=False)
test_dl = DataLoader(test_data, collate_fn=collate_fn, batch_size=BATCH_SIZE, shuffle=False)

# %%
vocab = Vocabulary([" ".join(example["tokens"]) for example in train_data], min_count=2, lower=True)

# %%
len(vocab)
# Out:
# 10946

# %%
ner_model = TokenClassificationModel(
    vocab_size=len(vocab),
    embedding_dim=w2v_model.vector_size,
    hidden_size=64,
    n_layers=2,
    n_classes=len(label2idx),
)

# %%
# инициализируйте эмбеддинги модели через эмбеддинги word2vec
# YOUR_CODE_HERE
for idx, token in vocab.idx2word.items():
    try:
        w2v_vector = w2v_model[token]
    except:
        print(f"No w2v embedding for word {token}")
        continue
    ner_model.embedding.weight.data[idx] = torch.tensor(w2v_vector)
# заморозьте слой эмбеддингов
# YOUR_CODE_HERE
ner_model.embedding.weight.requires_grad = False
# Out:
# No w2v embedding for word <PAD>
# No w2v embedding for word <SOS>
# No w2v embedding for word <EOS>
# No w2v embedding for word <UNK>
# No w2v embedding for word 1996-08-22
# No w2v embedding for word zwingmann
# No w2v embedding for word sheepmeat
# No w2v embedding for word fischler
# No w2v embedding for word spleens
# No w2v embedding for word spongiform
# No w2v embedding for word encephalopathy
# No w2v embedding for word scrapie
# No w2v embedding for word brain-wasting
# No w2v embedding for word 47,600
# No w2v embedding for word 4,275
# No w2v embedding for word 10
# No w2v embedding for word 17,000
# No w2v embedding for word 1966
# No w2v embedding for word 1967
# No w2v embedding for word 16
# No w2v embedding for word 1969
# No w2v embedding for word 1970
# No w2v embedding for word 27
# No w2v embedding for word shubei
# No w2v embedding for word ...
# No w2v embedding for word 14.2
# No w2v embedding for word year-earlier
# No w2v embedding for word 1996
# No w2v embedding for word 2.2
# No w2v embedding for word 1995
# No w2v embedding for word 11.7
# No w2v embedding for word simitis
# No w2v embedding for word skandalidis
# No w2v embedding for word kontogiannis
# No w2v embedding for word +301
# No w2v embedding for word 3311812-4
# No w2v embedding for word 100
# No w2v embedding for word vereinsbank
# No w2v embedding for word reoffer
# No w2v embedding for word denoms
# No w2v embedding for word 1-10-100
# No w2v embedding for word deflt
# No w2v embedding for word ctry
# No w2v embedding for word praecip
# No w2v embedding for word 7.0
# No w2v embedding for word 2001
# No w2v embedding for word +44
# No w2v embedding for word 171
# No w2v embedding for word 542
# No w2v embedding for word 7658
# No w2v embedding for word venantius
# No w2v embedding for word 300
# No w2v embedding for word 1999
# No w2v embedding for word 12.5
# No w2v embedding for word aa3
# No w2v embedding for word aa+
# No w2v embedding for word 2
# No w2v embedding for word 5
# No w2v embedding for word 24
# No w2v embedding for word rabinovich
# No w2v embedding for word preconditions
# No w2v embedding for word 1991
# No w2v embedding for word awdankiewicz
# No w2v embedding for word 800
# No w2v embedding for word khalq
# No w2v embedding for word kdpi
# No w2v embedding for word u.s.-led
# No w2v embedding for word 1/2
# No w2v embedding for word 5/8
# No w2v embedding for word israeli-plo
# No w2v embedding for word rdainah
# No w2v embedding for word allenby
# No w2v embedding for word 20s
# No w2v embedding for word 76
# No w2v embedding for word zhirinovsky
# No w2v embedding for word keenness
# No w2v embedding for word 1990
# No w2v embedding for word 22
# No w2v embedding for word 12
# No w2v embedding for word an-nahar
# No w2v embedding for word as-safir
# No w2v embedding for word ..
# No w2v embedding for word al-anwar
# No w2v embedding for word ad-diyar
# No w2v embedding for word al-watan
# No w2v embedding for word maronite
# No w2v embedding for word feedlot
# No w2v embedding for word kindercare
# No w2v embedding for word q1
# No w2v embedding for word 1.2
# No w2v embedding for word 1997
# No w2v embedding for word 1
# No w2v embedding for word 30
# No w2v embedding for word 12-month
# No w2v embedding for word 45
# No w2v embedding for word q2
# No w2v embedding for word 31
# No w2v embedding for word 2,383
# No w2v embedding for word 599
# No w2v embedding for word 565
# No w2v embedding for word 301
# No w2v embedding for word 0.19
# No w2v embedding for word 0.20
# No w2v embedding for word 93
# No w2v embedding for word 23
# No w2v embedding for word 8,000
# No w2v embedding for word +33
# No w2v embedding for word 42
# No w2v embedding for word 21
# No w2v embedding for word 53
# No w2v embedding for word 81
# No w2v embedding for word heidrun
# No w2v embedding for word 30,000
# No w2v embedding for word 50
# No w2v embedding for word 41
# No w2v embedding for word 3.8
# No w2v embedding for word markka
# No w2v embedding for word 96
# No w2v embedding for word jan-april
# No w2v embedding for word 95
# No w2v embedding for word 3.2
# No w2v embedding for word 14.5
# No w2v embedding for word 11.3
# No w2v embedding for word +358
# No w2v embedding for word 0
# No w2v embedding for word 680
# No w2v embedding for word 245
# No w2v embedding for word 99.95
# No w2v embedding for word 5.75
# No w2v embedding for word 2002
# No w2v embedding for word 15.00
# No w2v embedding for word 2.3
# No w2v embedding for word guilders
# No w2v embedding for word +31
# No w2v embedding for word 20
# No w2v embedding for word 504
# No w2v embedding for word 5000
# No w2v embedding for word 2.1
# No w2v embedding for word 7,149
# No w2v embedding for word 70
# No w2v embedding for word 66
# No w2v embedding for word goydos
# No w2v embedding for word hidemichi
# No w2v embedding for word 68
# No w2v embedding for word 69
# No w2v embedding for word forsbrand
# No w2v embedding for word 71
# No w2v embedding for word 72
# No w2v embedding for word struver
# No w2v embedding for word cejka
# No w2v embedding for word 73
# No w2v embedding for word weibring
# No w2v embedding for word 74
# No w2v embedding for word stankowski
# No w2v embedding for word 75
# No w2v embedding for word shigeki
# No w2v embedding for word 77
# No w2v embedding for word westner
# No w2v embedding for word schneiter
# No w2v embedding for word 79
# No w2v embedding for word bistrita
# No w2v embedding for word 2-1
# No w2v embedding for word 1-1
# No w2v embedding for word 32nd
# No w2v embedding for word voica
# No w2v embedding for word 84th
# No w2v embedding for word 24th
# No w2v embedding for word 4-2
# No w2v embedding for word 25
# No w2v embedding for word 100-30
# No w2v embedding for word nunthorpe
# No w2v embedding for word eveningperformance
# No w2v embedding for word 16-1
# No w2v embedding for word 11-4
# No w2v embedding for word 7-4
# No w2v embedding for word furlongs
# No w2v embedding for word 1.
# No w2v embedding for word 2.
# No w2v embedding for word 3.
# No w2v embedding for word 4th
# No w2v embedding for word 1996-08-21
# No w2v embedding for word 450,000
# No w2v embedding for word kijimuta
# No w2v embedding for word 1-6
# No w2v embedding for word 6-4
# No w2v embedding for word 6-3
# No w2v embedding for word 4
# No w2v embedding for word kamio
# No w2v embedding for word 6-2
# No w2v embedding for word 7-5
# No w2v embedding for word testud
# No w2v embedding for word 7
# No w2v embedding for word sugiyama
# No w2v embedding for word 4-6
# No w2v embedding for word 8
# No w2v embedding for word tauziat
# No w2v embedding for word shi-ting
# No w2v embedding for word waldbaum
# No w2v embedding for word bruguera
# No w2v embedding for word 3
# No w2v embedding for word reneberg
# No w2v embedding for word 3-6
# No w2v embedding for word 6
# No w2v embedding for word aynaoui
# No w2v embedding for word 5-7
# No w2v embedding for word 3-0
# No w2v embedding for word kucera
# No w2v embedding for word 7-6
# No w2v embedding for word 1994-95
# No w2v embedding for word 15
# No w2v embedding for word 326
# No w2v embedding for word 7-73
# No w2v embedding for word lathwell
# No w2v embedding for word 85
# No w2v embedding for word 280
# No w2v embedding for word 63
# No w2v embedding for word 52
# No w2v embedding for word 5-68
# No w2v embedding for word 59
# No w2v embedding for word 343-8
# No w2v embedding for word 108
# No w2v embedding for word 67
# No w2v embedding for word lenham
# No w2v embedding for word 145
# No w2v embedding for word 51
# No w2v embedding for word 392-6
# No w2v embedding for word 143
# No w2v embedding for word dowman
# No w2v embedding for word 107
# No w2v embedding for word 57
# No w2v embedding for word moxon
# No w2v embedding for word 44
# No w2v embedding for word 54
# No w2v embedding for word 94
# No w2v embedding for word 17
# No w2v embedding for word w-1
# No w2v embedding for word nb-8
# No w2v embedding for word 278
# No w2v embedding for word 1-64
# No w2v embedding for word 2-85
# No w2v embedding for word 3-116
# No w2v embedding for word 4-205
# No w2v embedding for word 5-248
# No w2v embedding for word 6-273
# No w2v embedding for word 12-1-41-1
# No w2v embedding for word 27-5-78-2
# No w2v embedding for word 6-1-17-0
# No w2v embedding for word inzamam-ul-haq
# No w2v embedding for word mujtaba
# No w2v embedding for word 20-month
# No w2v embedding for word 1994
# No w2v embedding for word under-21
# No w2v embedding for word tillstrom
# No w2v embedding for word ivanisevic
# No w2v embedding for word 6-7
# No w2v embedding for word 3-7
# No w2v embedding for word malivai
# No w2v embedding for word corretja
# No w2v embedding for word 7-3
# No w2v embedding for word philippoussis
# No w2v embedding for word rosset
# No w2v embedding for word 8-6
# No w2v embedding for word 9
# No w2v embedding for word pioline
# No w2v embedding for word 7-1
# No w2v embedding for word 11
# No w2v embedding for word berasategui
# No w2v embedding for word 6-1
# No w2v embedding for word clavet
# No w2v embedding for word vacek
# No w2v embedding for word 13
# No w2v embedding for word 13-11
# No w2v embedding for word 7-2
# No w2v embedding for word bohdan
# No w2v embedding for word ulihrach
# No w2v embedding for word gaudenzi
# No w2v embedding for word millns
# No w2v embedding for word chemlon
# No w2v embedding for word humenne
# No w2v embedding for word 0-0
# No w2v embedding for word 50th
# No w2v embedding for word 54th
# No w2v embedding for word 5,000
# No w2v embedding for word chorzow
# No w2v embedding for word 1-0
# No w2v embedding for word 1st
# No w2v embedding for word 55th
# No w2v embedding for word 47th
# No w2v embedding for word 63rd
# No w2v embedding for word 6,500
# No w2v embedding for word 2-0
# No w2v embedding for word 28th
# No w2v embedding for word alexandrou
# No w2v embedding for word 41st
# No w2v embedding for word 60th
# No w2v embedding for word 82nd
# No w2v embedding for word 5-1
# No w2v embedding for word siauliai
# No w2v embedding for word vinnytsya
# No w2v embedding for word nyva
# No w2v embedding for word 3,000
# No w2v embedding for word 2-2
# No w2v embedding for word 10th
# No w2v embedding for word 5th
# No w2v embedding for word 5-2
# No w2v embedding for word 58th
# No w2v embedding for word 25,000
# No w2v embedding for word 4-3
# No w2v embedding for word vaduz
# No w2v embedding for word 90th
# No w2v embedding for word varteks
# No w2v embedding for word varazdin
# No w2v embedding for word 78th
# No w2v embedding for word 87th
# No w2v embedding for word 0-2
# No w2v embedding for word 4-0
# No w2v embedding for word 26th
# No w2v embedding for word 19th
# No w2v embedding for word 48th
# No w2v embedding for word 80th
# No w2v embedding for word 76th
# No w2v embedding for word 86th
# No w2v embedding for word 44th
# No w2v embedding for word 59th
# No w2v embedding for word constructorul
# No w2v embedding for word mypa-47
# No w2v embedding for word kispest
# No w2v embedding for word honved
# No w2v embedding for word rishon
# No w2v embedding for word 42nd
# No w2v embedding for word gennadi
# No w2v embedding for word 1,500
# No w2v embedding for word ferencvaros
# No w2v embedding for word 4-1
# No w2v embedding for word 15th
# No w2v embedding for word 9,000
# No w2v embedding for word newcombe
# No w2v embedding for word woodforde
# No w2v embedding for word 1986
# No w2v embedding for word 9/16
# No w2v embedding for word yigang
# No w2v embedding for word 15-3
# No w2v embedding for word 15-7
# No w2v embedding for word 15-2
# No w2v embedding for word 17-14
# No w2v embedding for word kantharoopan
# No w2v embedding for word 3/4
# No w2v embedding for word 15-11
# No w2v embedding for word 15-6
# No w2v embedding for word zhilan
# No w2v embedding for word 15-8
# No w2v embedding for word 15-12
# No w2v embedding for word 2nd
# No w2v embedding for word 11-3
# No w2v embedding for word 11-6
# No w2v embedding for word 11-8
# No w2v embedding for word 11-2
# No w2v embedding for word 11-1
# No w2v embedding for word 6-11
# No w2v embedding for word 11-7
# No w2v embedding for word voinea
# No w2v embedding for word olhovskiy
# No w2v embedding for word bjorkman
# No w2v embedding for word rikl
# No w2v embedding for word sjeng
# No w2v embedding for word schalken
# No w2v embedding for word meligeni
# No w2v embedding for word kafelnikov
# No w2v embedding for word fleurian
# No w2v embedding for word kroslak
# No w2v embedding for word 14
# No w2v embedding for word wilander
# No w2v embedding for word haarhuis
# No w2v embedding for word tebbutt
# No w2v embedding for word karbacher
# No w2v embedding for word krajicek
# No w2v embedding for word ondruska
# No w2v embedding for word siemerink
# No w2v embedding for word carl-uwe
# No w2v embedding for word steeb
# No w2v embedding for word lapentti
# No w2v embedding for word enqvist
# No w2v embedding for word raoux
# No w2v embedding for word dewulf
# No w2v embedding for word filippini
# No w2v embedding for word sandon
# No w2v embedding for word stolle
# No w2v embedding for word pescosolido
# No w2v embedding for word tarango
# No w2v embedding for word radulescu
# No w2v embedding for word kulti
# No w2v embedding for word hlasek
# No w2v embedding for word mamiit
# No w2v embedding for word prinosil
# No w2v embedding for word etchebarren
# No w2v embedding for word tabulate
# No w2v embedding for word 58
# No w2v embedding for word .536
# No w2v embedding for word 64
# No w2v embedding for word .496
# No w2v embedding for word .457
# No w2v embedding for word 82
# No w2v embedding for word 28
# No w2v embedding for word .598
# No w2v embedding for word .539
# No w2v embedding for word .500
# No w2v embedding for word 60
# No w2v embedding for word .469
# No w2v embedding for word 18
# No w2v embedding for word .575
# No w2v embedding for word 61
# No w2v embedding for word .512
# No w2v embedding for word 62
# No w2v embedding for word .481
# No w2v embedding for word 46
# No w2v embedding for word .461
# No w2v embedding for word .535
# No w2v embedding for word .532
# No w2v embedding for word .504
# No w2v embedding for word .543
# No w2v embedding for word 65
# No w2v embedding for word .435
# No w2v embedding for word 10-8
# No w2v embedding for word right-field
# No w2v embedding for word 40
# No w2v embedding for word 2/3
# No w2v embedding for word 30th
# No w2v embedding for word fifth-inning
# No w2v embedding for word 5-5
# No w2v embedding for word 21st
# No w2v embedding for word major-league
# No w2v embedding for word 34
# No w2v embedding for word 22nd
# No w2v embedding for word 1/3
# No w2v embedding for word 27th
# No w2v embedding for word eighth-inning
# No w2v embedding for word four-run
# No w2v embedding for word six-hitter
# No w2v embedding for word five-run
# No w2v embedding for word 10-7
# No w2v embedding for word nilis
# No w2v embedding for word 11th
# No w2v embedding for word 67th
# No w2v embedding for word 1-2
# No w2v embedding for word knup
# No w2v embedding for word 26
# No w2v embedding for word 40,000
# No w2v embedding for word 1,000
# No w2v embedding for word broadhurst
# No w2v embedding for word woosnam
# No w2v embedding for word claydon
# No w2v embedding for word retief
# No w2v embedding for word suneson
# No w2v embedding for word pyman
# No w2v embedding for word cevaer
# No w2v embedding for word hawksworth
# No w2v embedding for word gogele
# No w2v embedding for word jonzon
# No w2v embedding for word eales
# No w2v embedding for word coltart
# No w2v embedding for word linhart
# No w2v embedding for word 1997-98
# No w2v embedding for word 8.62
# No w2v embedding for word 8.61
# No w2v embedding for word 8.57
# No w2v embedding for word 4.
# No w2v embedding for word 5.
# No w2v embedding for word 6.
# No w2v embedding for word 7.
# No w2v embedding for word 8.
# No w2v embedding for word 9.
# No w2v embedding for word 10.
# No w2v embedding for word 8.30
# No w2v embedding for word 13.
# No w2v embedding for word 8.29
# No w2v embedding for word 15.
# No w2v embedding for word 16.
# No w2v embedding for word 8.22
# No w2v embedding for word 18.
# No w2v embedding for word 19.
# No w2v embedding for word 20.
# No w2v embedding for word 21.
# No w2v embedding for word 8.15
# No w2v embedding for word 23.
# No w2v embedding for word 8.12
# No w2v embedding for word 26.
# No w2v embedding for word 8.09
# No w2v embedding for word 8.05
# No w2v embedding for word 33.
# No w2v embedding for word 8.02
# No w2v embedding for word 37.
# No w2v embedding for word 7.89
# No w2v embedding for word 7.40
# No w2v embedding for word plainclothes
# No w2v embedding for word 251
# No w2v embedding for word 119
# No w2v embedding for word 35
# No w2v embedding for word 359-2-84561
# No w2v embedding for word 211
# No w2v embedding for word corrigendum
# No w2v embedding for word 187
# No w2v embedding for word 91
# No w2v embedding for word hcfa
# No w2v embedding for word gildea
# No w2v embedding for word 312-408-8787
# No w2v embedding for word 3-1/2
# No w2v embedding for word 169
# No w2v embedding for word 29
# No w2v embedding for word 0.23
# No w2v embedding for word 1996-08-23
# No w2v embedding for word 1940
# No w2v embedding for word 1949
# No w2v embedding for word +17
# No w2v embedding for word +22
# No w2v embedding for word +6
# No w2v embedding for word +4
# No w2v embedding for word 1989
# No w2v embedding for word 1982
# No w2v embedding for word 115
# No w2v embedding for word 900
# No w2v embedding for word 39
# No w2v embedding for word 4,500
# No w2v embedding for word 8.5
# No w2v embedding for word berkrot
# No w2v embedding for word 19-year-old
# No w2v embedding for word zvereva
# No w2v embedding for word fifth-seeded
# No w2v embedding for word one-match
# No w2v embedding for word eighth-seeded
# No w2v embedding for word coetzer
# No w2v embedding for word 16th
# No w2v embedding for word novotna
# No w2v embedding for word ruxandra
# No w2v embedding for word dragomir
# No w2v embedding for word 61-2
# No w2v embedding for word 9373-1800
# No w2v embedding for word unseeded
# No w2v embedding for word 55
# No w2v embedding for word third-set
# No w2v embedding for word 13th
# No w2v embedding for word 2-5
# No w2v embedding for word 32
# No w2v embedding for word 24-year-old
# No w2v embedding for word pro-soccer
# No w2v embedding for word chonnam
# No w2v embedding for word puchon
# No w2v embedding for word chonan
# No w2v embedding for word chonbuk
# No w2v embedding for word 160
# No w2v embedding for word ecomog
# No w2v embedding for word 60,000
# No w2v embedding for word 10,000
# No w2v embedding for word lansana
# No w2v embedding for word 1984
# No w2v embedding for word 1993
# No w2v embedding for word 7.8
# No w2v embedding for word jan-may
# No w2v embedding for word 934
# No w2v embedding for word jan-june
# No w2v embedding for word 27,246.5
# No w2v embedding for word 14,390.7
# No w2v embedding for word 10.6
# No w2v embedding for word 102
# No w2v embedding for word 122
# No w2v embedding for word t-bill
# No w2v embedding for word 1998
# No w2v embedding for word 36
# No w2v embedding for word 266
# No w2v embedding for word 2410
# No w2v embedding for word 200
# No w2v embedding for word lebed
# No w2v embedding for word chief-of-staff
# No w2v embedding for word maskhadov
# No w2v embedding for word 0800
# No w2v embedding for word 1500
# No w2v embedding for word 1600
# No w2v embedding for word 13-year-old
# No w2v embedding for word zlotys
# No w2v embedding for word sierakowice
# No w2v embedding for word cnb-120
# No w2v embedding for word 869.3
# No w2v embedding for word 14.4
# No w2v embedding for word 42-2-2423-0003
# No w2v embedding for word novye
# No w2v embedding for word atagi
# No w2v embedding for word itar-tass
# No w2v embedding for word russian-chechen
# No w2v embedding for word mirhunisa
# No w2v embedding for word komarica
# No w2v embedding for word 2,400
# No w2v embedding for word 1,900
# No w2v embedding for word alkhan-yurt
# No w2v embedding for word 14.8
# No w2v embedding for word 1.9
# No w2v embedding for word 0.1
# No w2v embedding for word 0.8
# No w2v embedding for word 4.2
# No w2v embedding for word 1992
# No w2v embedding for word 1980
# No w2v embedding for word brunswijk
# No w2v embedding for word 56
# No w2v embedding for word 90
# No w2v embedding for word 500
# No w2v embedding for word 1980s
# No w2v embedding for word mid-1997
# No w2v embedding for word self-rule
# No w2v embedding for word israel-plo
# No w2v embedding for word egyptair
# No w2v embedding for word 7.2
# No w2v embedding for word 65,000
# No w2v embedding for word 67,000
# No w2v embedding for word 0.47
# No w2v embedding for word 0.55
# No w2v embedding for word 218
# No w2v embedding for word 19
# No w2v embedding for word 112
# No w2v embedding for word 40-year-old
# No w2v embedding for word 37th
# No w2v embedding for word 1.82
# No w2v embedding for word baa1
# No w2v embedding for word 212-859-1650
# No w2v embedding for word lauck
# No w2v embedding for word 43-year-old
# No w2v embedding for word neo-nazism
# No w2v embedding for word 1970s
# No w2v embedding for word nsdap-ao
# No w2v embedding for word oil-for-food
# No w2v embedding for word undersecretary-general
# No w2v embedding for word claverie
# No w2v embedding for word 50,000
# No w2v embedding for word 110
# No w2v embedding for word january-july
# No w2v embedding for word 5.9
# No w2v embedding for word 3.1
# No w2v embedding for word 202
# No w2v embedding for word 16.8
# No w2v embedding for word 11.4
# No w2v embedding for word 4.4
# No w2v embedding for word 1.5
# No w2v embedding for word 3.5
# No w2v embedding for word 11.8
# No w2v embedding for word 382
# No w2v embedding for word 17.8
# No w2v embedding for word tel+44
# No w2v embedding for word 161
# No w2v embedding for word 7706
# No w2v embedding for word fax+44
# No w2v embedding for word 5017
# No w2v embedding for word 2.75
# No w2v embedding for word 5040
# No w2v embedding for word ballybunion
# No w2v embedding for word erdmann
# No w2v embedding for word ischinger
# No w2v embedding for word primakov
# No w2v embedding for word kinkel
# No w2v embedding for word 1974
# No w2v embedding for word ctbt
# No w2v embedding for word under-secretary
# No w2v embedding for word 1987
# No w2v embedding for word 1947
# No w2v embedding for word 20,000
# No w2v embedding for word 0.7
# No w2v embedding for word rangarajan
# No w2v embedding for word 16-17
# No w2v embedding for word +91-22-265
# No w2v embedding for word 9000
# No w2v embedding for word 1979
# No w2v embedding for word 86
# No w2v embedding for word 80
# No w2v embedding for word hriday
# No w2v embedding for word 150
# No w2v embedding for word 18,000
# No w2v embedding for word 1995/96
# No w2v embedding for word 1996/97
# No w2v embedding for word pre-abnormals
# No w2v embedding for word harper-collins
# No w2v embedding for word 2.00
# No w2v embedding for word 0400
# No w2v embedding for word 0.79
# No w2v embedding for word 373-1800
# No w2v embedding for word 1998/99
# No w2v embedding for word 10.5
# No w2v embedding for word 11.25
# No w2v embedding for word 4734
# No w2v embedding for word 746
# No w2v embedding for word odv
# No w2v embedding for word klongprem
# No w2v embedding for word year-ago
# No w2v embedding for word 400
# No w2v embedding for word 250
# No w2v embedding for word 84
# No w2v embedding for word 11.61
# No w2v embedding for word 3.92
# No w2v embedding for word 10.00
# No w2v embedding for word 43
# No w2v embedding for word 852
# No w2v embedding for word nitrofuran
# No w2v embedding for word 2000
# No w2v embedding for word sukarnoputri
# No w2v embedding for word 0.48
# No w2v embedding for word 43.50
# No w2v embedding for word wholly-owned
# No w2v embedding for word 5,778.00
# No w2v embedding for word 3,907.5
# No w2v embedding for word 2,583.49
# No w2v embedding for word ....
# No w2v embedding for word cac-40
# No w2v embedding for word inter-ethnic
# No w2v embedding for word post-soviet
# No w2v embedding for word kuchma
# No w2v embedding for word hryvna
# No w2v embedding for word karbovanets
# No w2v embedding for word 33
# No w2v embedding for word buzuku
# No w2v embedding for word unimported
# No w2v embedding for word 4.9
# No w2v embedding for word 180
# No w2v embedding for word +7095
# No w2v embedding for word 941
# No w2v embedding for word 8520
# No w2v embedding for word 175
# No w2v embedding for word 1230
# No w2v embedding for word 1800
# No w2v embedding for word spa-francorchamps
# No w2v embedding for word heinz-harald
# No w2v embedding for word frentzen
# No w2v embedding for word 11.
# No w2v embedding for word 12.
# No w2v embedding for word ligier
# No w2v embedding for word studenikova
# No w2v embedding for word habsudova
# No w2v embedding for word 298-6
# No w2v embedding for word 105
# No w2v embedding for word 255-3
# No w2v embedding for word 389
# No w2v embedding for word 4-36
# No w2v embedding for word 310
# No w2v embedding for word 83
# No w2v embedding for word munton
# No w2v embedding for word illingworth
# No w2v embedding for word 4-54
# No w2v embedding for word lampitt
# No w2v embedding for word 4-90
# No w2v embedding for word 529-8
# No w2v embedding for word 181
# No w2v embedding for word 109
# No w2v embedding for word 162-4
# No w2v embedding for word fairbrother
# No w2v embedding for word 106
# No w2v embedding for word 116
# No w2v embedding for word 1-106
# No w2v embedding for word 4-95
# No w2v embedding for word sixth-seeded
# No w2v embedding for word 2-6
# No w2v embedding for word 12th-ranked
# No w2v embedding for word 26-year-old
# No w2v embedding for word markgraaff
# No w2v embedding for word snyman
# No w2v embedding for word 15-10
# No w2v embedding for word 15-5
# No w2v embedding for word 5-4
# No w2v embedding for word 15-9
# No w2v embedding for word .450
# No w2v embedding for word .578
# No w2v embedding for word .516
# No w2v embedding for word .477
# No w2v embedding for word .465
# No w2v embedding for word 47
# No w2v embedding for word .406
# No w2v embedding for word .531
# No w2v embedding for word .528
# No w2v embedding for word .425
# No w2v embedding for word 10-3
# No w2v embedding for word 10-2
# No w2v embedding for word coppinger
# No w2v embedding for word buhner
# No w2v embedding for word 7-0
# No w2v embedding for word pinch-hitter
# No w2v embedding for word 0-1
# No w2v embedding for word six-run
# No w2v embedding for word 12-8
# No w2v embedding for word 14-7
# No w2v embedding for word outdueled
# No w2v embedding for word 11-15
# No w2v embedding for word predrosa
# No w2v embedding for word 3-1
# No w2v embedding for word 35th
# No w2v embedding for word 38th
# No w2v embedding for word 57th
# No w2v embedding for word trulsen
# No w2v embedding for word 64th
# No w2v embedding for word baeron
# No w2v embedding for word hissou
# No w2v embedding for word 38.08
# No w2v embedding for word 34th
# No w2v embedding for word 15,000
# No w2v embedding for word masterkova
# No w2v embedding for word 28.98
# No w2v embedding for word 2:29.34
# No w2v embedding for word mutola
# No w2v embedding for word 2:29.66
# No w2v embedding for word 100,000
# No w2v embedding for word tabulated
# No w2v embedding for word 2:28.98
# No w2v embedding for word 128
# No w2v embedding for word 129
# No w2v embedding for word 130
# No w2v embedding for word 131
# No w2v embedding for word 132
# No w2v embedding for word 133
# No w2v embedding for word 10.03
# No w2v embedding for word 1988
# No w2v embedding for word 10.09
# No w2v embedding for word 10.10
# No w2v embedding for word 10.12
# No w2v embedding for word 10.14
# No w2v embedding for word 12.92
# No w2v embedding for word 13.24
# No w2v embedding for word engquist
# No w2v embedding for word 12.60
# No w2v embedding for word bukovec
# No w2v embedding for word 12.95
# No w2v embedding for word 12.77
# No w2v embedding for word aliuska
# No w2v embedding for word 47.93
# No w2v embedding for word 10.84
# No w2v embedding for word 0.10
# No w2v embedding for word merlene
# No w2v embedding for word ottey
# No w2v embedding for word 11.04
# No w2v embedding for word 11.00
# No w2v embedding for word 61.36
# No w2v embedding for word 13.36
# No w2v embedding for word ezinwa
# No w2v embedding for word 10.15
# No w2v embedding for word ottoz
# No w2v embedding for word onyali
# No w2v embedding for word privalova
# No w2v embedding for word 11.28
# No w2v embedding for word voronova
# No w2v embedding for word kosgei
# No w2v embedding for word kamoga
# No w2v embedding for word 20.42
# No w2v embedding for word 20.45
# No w2v embedding for word sturrup
# No w2v embedding for word falilat
# No w2v embedding for word ogunkoya
# No w2v embedding for word 50.14
# No w2v embedding for word 16.66
# No w2v embedding for word tanui
# No w2v embedding for word 2.03
# No w2v embedding for word 1.88
# No w2v embedding for word 1.85
# No w2v embedding for word koech
# No w2v embedding for word 18-man
# No w2v embedding for word vogts
# No w2v embedding for word zabrze
# No w2v embedding for word koepke
# No w2v embedding for word haessler
# No w2v embedding for word bobic
# No w2v embedding for word ekeren
# No w2v embedding for word off-spinner
# No w2v embedding for word muralitharan
# No w2v embedding for word three-test
# No w2v embedding for word ranatunga
# No w2v embedding for word battersby
# No w2v embedding for word gencor
# No w2v embedding for word primedia
# No w2v embedding for word iscor
# No w2v embedding for word 38.0
# No w2v embedding for word imphold
# No w2v embedding for word 33.0
# No w2v embedding for word +27
# No w2v embedding for word petroleums
# No w2v embedding for word 0.04
# No w2v embedding for word 0.08
# No w2v embedding for word 0.12
# No w2v embedding for word 0.15
# No w2v embedding for word 0.86
# No w2v embedding for word 000s
# No w2v embedding for word 416
# No w2v embedding for word 941-8100
# No w2v embedding for word axworthy
# No w2v embedding for word 0.25
# No w2v embedding for word 0.50
# No w2v embedding for word 120,000
# No w2v embedding for word unitog
# No w2v embedding for word 8.0
# No w2v embedding for word 2-1/2
# No w2v embedding for word w145
# No w2v embedding for word 31/8
# No w2v embedding for word caribs
# No w2v embedding for word 03/09
# No w2v embedding for word 185,000
# No w2v embedding for word 229-1
# No w2v embedding for word taibe
# No w2v embedding for word 28,000
# No w2v embedding for word yihye
# No w2v embedding for word liechenstein
# No w2v embedding for word 1990s
# No w2v embedding for word 1968
# No w2v embedding for word 1985
# No w2v embedding for word 800,000
# No w2v embedding for word 1.1
# No w2v embedding for word hutus
# No w2v embedding for word krajina
# No w2v embedding for word 200,000
# No w2v embedding for word goncharova
# No w2v embedding for word granic
# No w2v embedding for word 1000
# No w2v embedding for word tanjug
# No w2v embedding for word hovercrafts
# No w2v embedding for word pro-baghdad
# No w2v embedding for word 1950s
# No w2v embedding for word sirnak
# No w2v embedding for word 12-year-old
# No w2v embedding for word u.s.-mediated
# No w2v embedding for word pelletreau
# No w2v embedding for word aflatoxin
# No w2v embedding for word 1.7
# No w2v embedding for word freight-tonne
# No w2v embedding for word 1,600
# No w2v embedding for word 820
# No w2v embedding for word 125
# No w2v embedding for word 82-96f
# No w2v embedding for word 28-36c
# No w2v embedding for word 0.75
# No w2v embedding for word 13-year
# No w2v embedding for word birendra
# No w2v embedding for word 1972
# No w2v embedding for word munakarmi
# No w2v embedding for word euromark
# No w2v embedding for word 20.00
# No w2v embedding for word 3.00
# No w2v embedding for word 3.30
# No w2v embedding for word 10-year
# No w2v embedding for word high-yielding
# No w2v embedding for word american-style
# No w2v embedding for word 25.00
# No w2v embedding for word paydate
# No w2v embedding for word 30.aug.96
# No w2v embedding for word stenning
# No w2v embedding for word birnberg
# No w2v embedding for word 282
# No w2v embedding for word dohuk
# No w2v embedding for word solidere
# No w2v embedding for word 106.5
# No w2v embedding for word ciments
# No w2v embedding for word 0.02
# No w2v embedding for word 961
# No w2v embedding for word luehrs
# No w2v embedding for word 5.50
# No w2v embedding for word americast
# No w2v embedding for word 97
# No w2v embedding for word enderle
# No w2v embedding for word 8.67
# No w2v embedding for word 4.0
# No w2v embedding for word hijackings
# No w2v embedding for word w-2
# No w2v embedding for word everen
# No w2v embedding for word 0.40
# No w2v embedding for word checkfree
# No w2v embedding for word 212
# No w2v embedding for word 859-1610
# No w2v embedding for word guilder
# No w2v embedding for word boskalis
# No w2v embedding for word costis
# No w2v embedding for word grech
# No w2v embedding for word h1
# No w2v embedding for word 188
# No w2v embedding for word 3.3
# No w2v embedding for word 6.4
# No w2v embedding for word 5,400
# No w2v embedding for word 4.6
# No w2v embedding for word 5.1
# No w2v embedding for word 3.7
# No w2v embedding for word +49
# No w2v embedding for word 756525
# No w2v embedding for word 5.6
# No w2v embedding for word 2,000
# No w2v embedding for word niugini
# No w2v embedding for word 38
# No w2v embedding for word 3.75
# No w2v embedding for word 96/97
# No w2v embedding for word 371
# No w2v embedding for word 447
# No w2v embedding for word 48.61
# No w2v embedding for word 286
# No w2v embedding for word 48
# No w2v embedding for word 350
# No w2v embedding for word yingkou
# No w2v embedding for word cniec
# No w2v embedding for word backwardation
# No w2v embedding for word 85,000
# No w2v embedding for word 2,700
# No w2v embedding for word 1.8
# No w2v embedding for word 2843
# No w2v embedding for word 6368
# No w2v embedding for word promodes
# No w2v embedding for word superstores
# No w2v embedding for word 4.7
# No w2v embedding for word 4221
# No w2v embedding for word 5452
# No w2v embedding for word 1996-08-24
# No w2v embedding for word jiangling
# No w2v embedding for word kankkunen
# No w2v embedding for word jyvaskyla
# No w2v embedding for word 37
# No w2v embedding for word gronholm
# No w2v embedding for word makinen
# No w2v embedding for word 250,000
# No w2v embedding for word 6.5
# No w2v embedding for word 37-year-old
# No w2v embedding for word 14.
# No w2v embedding for word verstappen
# No w2v embedding for word 17.
# No w2v embedding for word katayama
# No w2v embedding for word richardt
# No w2v embedding for word +1
# No w2v embedding for word +2
# No w2v embedding for word +3
# No w2v embedding for word +5
# No w2v embedding for word +7
# No w2v embedding for word +11
# No w2v embedding for word 78
# No w2v embedding for word 902
# No w2v embedding for word 884
# No w2v embedding for word 441
# No w2v embedding for word 767
# No w2v embedding for word 409
# No w2v embedding for word 555
# No w2v embedding for word 499
# No w2v embedding for word 462
# No w2v embedding for word 548
# No w2v embedding for word 681
# No w2v embedding for word 398
# No w2v embedding for word 795
# No w2v embedding for word 325
# No w2v embedding for word 1021
# No w2v embedding for word ilott
# No w2v embedding for word 88
# No w2v embedding for word second-placed
# No w2v embedding for word 353
# No w2v embedding for word arch-rivals
# No w2v embedding for word 206
# No w2v embedding for word 323
# No w2v embedding for word 210
# No w2v embedding for word 176
# No w2v embedding for word b-4
# No w2v embedding for word lb-3
# No w2v embedding for word 339
# No w2v embedding for word 2-239
# No w2v embedding for word 3-334
# No w2v embedding for word 4-334
# No w2v embedding for word 532-8
# No w2v embedding for word 111
# No w2v embedding for word 4-80
# No w2v embedding for word 361
# No w2v embedding for word 117
# No w2v embedding for word 446-9
# No w2v embedding for word 128-4
# No w2v embedding for word 205-9
# No w2v embedding for word spiring
# No w2v embedding for word watkinson
# No w2v embedding for word 4-53
# No w2v embedding for word airdrieonians
# No w2v embedding for word stenhousemuir
# No w2v embedding for word 318-2
# No w2v embedding for word 0-6
# No w2v embedding for word 33-26
# No w2v embedding for word westhuizen
# No w2v embedding for word zinzan
# No w2v embedding for word stranksy
# No w2v embedding for word culhane
# No w2v embedding for word cukaricki
# No w2v embedding for word becej
# No w2v embedding for word borac
# No w2v embedding for word zemun
# No w2v embedding for word proleter
# No w2v embedding for word loznica
# No w2v embedding for word obilic
# No w2v embedding for word kikinda
# No w2v embedding for word radnicki
# No w2v embedding for word rudar
# No w2v embedding for word wronki
# No w2v embedding for word hutnik
# No w2v embedding for word tychy
# No w2v embedding for word rakow
# No w2v embedding for word czestochowa
# No w2v embedding for word stomil
# No w2v embedding for word olsztyn
# No w2v embedding for word gornik
# No w2v embedding for word odra
# No w2v embedding for word wodzislaw
# No w2v embedding for word zaglebie
# No w2v embedding for word belchatow
# No w2v embedding for word pro-league
# No w2v embedding for word pro-baseball
# No w2v embedding for word haitai
# No w2v embedding for word ssangbangwool
# No w2v embedding for word .471
# No w2v embedding for word .455
# No w2v embedding for word .359
# No w2v embedding for word .473
# No w2v embedding for word .574
# No w2v embedding for word .411
# No w2v embedding for word .527
# No w2v embedding for word .430
# No w2v embedding for word .538
# No w2v embedding for word veldman
# No w2v embedding for word tomasson
# No w2v embedding for word mouscron
# No w2v embedding for word truiden
# No w2v embedding for word drobnjak
# No w2v embedding for word gravelaine
# No w2v embedding for word miladin
# No w2v embedding for word becanovic
# No w2v embedding for word scifo
# No w2v embedding for word smicer
# No w2v embedding for word wreh
# No w2v embedding for word 52nd
# No w2v embedding for word 16,000
# No w2v embedding for word debbah
# No w2v embedding for word 39th
# No w2v embedding for word 6,000
# No w2v embedding for word 79th
# No w2v embedding for word 65th
# No w2v embedding for word 69th
# No w2v embedding for word 70th
# No w2v embedding for word caveglia
# No w2v embedding for word 89th
# No w2v embedding for word 7,000
# No w2v embedding for word 8th
# No w2v embedding for word 66th
# No w2v embedding for word 33rd
# No w2v embedding for word 45th
# No w2v embedding for word 1860
# No w2v embedding for word 73rd
# No w2v embedding for word 9th
# No w2v embedding for word linzer
# No w2v embedding for word 300,000
# No w2v embedding for word 339-4
# No w2v embedding for word nijmeh
# No w2v embedding for word eco-challenge
# No w2v embedding for word 1983
# No w2v embedding for word tutsi-dominated
# No w2v embedding for word zairean
# No w2v embedding for word tutsis
# No w2v embedding for word gisenyi
# No w2v embedding for word hintsa
# No w2v embedding for word gcaleka
# No w2v embedding for word kassala
# No w2v embedding for word gyaicain
# No w2v embedding for word resalat
# No w2v embedding for word 419
# No w2v embedding for word khalfallah
# No w2v embedding for word moada
# No w2v embedding for word 1978
# No w2v embedding for word boutros-ghali
# No w2v embedding for word 44.2
# No w2v embedding for word ruehe
# No w2v embedding for word nato-led
# No w2v embedding for word cimicchi
# No w2v embedding for word etruria
# No w2v embedding for word stevanin
# No w2v embedding for word 35-year-old
# No w2v embedding for word passer-by
# No w2v embedding for word bourlet
# No w2v embedding for word lambrecks
# No w2v embedding for word 25-year-old
# No w2v embedding for word 1,400
# No w2v embedding for word 7.5
# No w2v embedding for word 1996-08-25
# No w2v embedding for word javasoft
# No w2v embedding for word verisign
# No w2v embedding for word 277
# No w2v embedding for word three-stroke
# No w2v embedding for word 12th
# No w2v embedding for word no.2
# No w2v embedding for word 17th
# No w2v embedding for word bogeyed
# No w2v embedding for word 14th
# No w2v embedding for word 274
# No w2v embedding for word 281
# No w2v embedding for word 283
# No w2v embedding for word 290
# No w2v embedding for word 295
# No w2v embedding for word 6-0
# No w2v embedding for word jyvasklya
# No w2v embedding for word kytolehto
# No w2v embedding for word 2:23
# No w2v embedding for word 500cc
# No w2v embedding for word smets
# No w2v embedding for word theybers
# No w2v embedding for word 236
# No w2v embedding for word 219
# No w2v embedding for word 178
# No w2v embedding for word 125cc
# No w2v embedding for word tortelli
# No w2v embedding for word seguy
# No w2v embedding for word camerlengo
# No w2v embedding for word belometti
# No w2v embedding for word vialle
# No w2v embedding for word dugmore
# No w2v embedding for word 432
# No w2v embedding for word 317
# No w2v embedding for word 293
# No w2v embedding for word 192
# No w2v embedding for word 152
# No w2v embedding for word olofsson
# No w2v embedding for word ennea
# No w2v embedding for word f40
# No w2v embedding for word 170
# No w2v embedding for word bscher
# No w2v embedding for word f1
# No w2v embedding for word 167
# No w2v embedding for word owen-jones
# No w2v embedding for word raphanel
# No w2v embedding for word gounon
# No w2v embedding for word gt2
# No w2v embedding for word 911
# No w2v embedding for word 164
# No w2v embedding for word 162
# No w2v embedding for word 156
# No w2v embedding for word 98
# No w2v embedding for word 60.66
# No w2v embedding for word 5.60
# No w2v embedding for word pukstys
# No w2v embedding for word 82.20
# No w2v embedding for word 2.30
# No w2v embedding for word malakwen
# No w2v embedding for word 15.125
# No w2v embedding for word 208.442
# No w2v embedding for word 149
# No w2v embedding for word radstrom
# No w2v embedding for word corser
# No w2v embedding for word kocinski
# No w2v embedding for word takeishi
# No w2v embedding for word 147.159
# No w2v embedding for word 38:18.759
# No w2v embedding for word 38:19.313
# No w2v embedding for word 38:32.149
# No w2v embedding for word 38:32.719
# No w2v embedding for word 38:33.595
# No w2v embedding for word 38:34.682
# No w2v embedding for word 38:34.999
# No w2v embedding for word 38:35.297
# No w2v embedding for word 38:42.015
# No w2v embedding for word 147.786
# No w2v embedding for word 269
# No w2v embedding for word 254
# No w2v embedding for word crafar
# No w2v embedding for word 238
# No w2v embedding for word 611
# No w2v embedding for word 667
# No w2v embedding for word 576
# No w2v embedding for word 730
# No w2v embedding for word 473
# No w2v embedding for word 745
# No w2v embedding for word 154
# No w2v embedding for word byas
# No w2v embedding for word 74-0
# No w2v embedding for word 521-8
# No w2v embedding for word 51st
# No w2v embedding for word 521
# No w2v embedding for word 2-1-4-0
# No w2v embedding for word 473-6
# No w2v embedding for word 87
# No w2v embedding for word bachirou
# No w2v embedding for word 53rd
# No w2v embedding for word widzew
# No w2v embedding for word mieciel
# No w2v embedding for word ceahlaul
# No w2v embedding for word piatra
# No w2v embedding for word neamt
# No w2v embedding for word otelul
# No w2v embedding for word arges
# No w2v embedding for word pitesti
# No w2v embedding for word chindia
# No w2v embedding for word tirgoviste
# No w2v embedding for word sportul
# No w2v embedding for word studentesc
# No w2v embedding for word universitatea
# No w2v embedding for word politehnica
# No w2v embedding for word jiul
# No w2v embedding for word petrosani
# No w2v embedding for word alaniya
# No w2v embedding for word zhemchuzhina
# No w2v embedding for word baltika
# No w2v embedding for word chernomorets
# No w2v embedding for word novorossiisk
# No w2v embedding for word rostselmash
# No w2v embedding for word naberezhnye
# No w2v embedding for word togliatti
# No w2v embedding for word kamyshin
# No w2v embedding for word krylya
# No w2v embedding for word sovetov
# No w2v embedding for word uralmash
# No w2v embedding for word 49
# No w2v embedding for word 14.12
# No w2v embedding for word 153
# No w2v embedding for word 151
# No w2v embedding for word 11.12
# No w2v embedding for word 28.19
# No w2v embedding for word 13.18
# No w2v embedding for word 9.12
# No w2v embedding for word 14.16
# No w2v embedding for word 12.10
# No w2v embedding for word 10.11
# No w2v embedding for word 16.13
# No w2v embedding for word 2123
# No w2v embedding for word 1631
# No w2v embedding for word 130.2
# No w2v embedding for word 2067
# No w2v embedding for word 1687
# No w2v embedding for word 122.5
# No w2v embedding for word 2151
# No w2v embedding for word 1673
# No w2v embedding for word 128.6
# No w2v embedding for word 2385
# No w2v embedding for word 1873
# No w2v embedding for word 127.3
# No w2v embedding for word 2009
# No w2v embedding for word 1844
# No w2v embedding for word 108.9
# No w2v embedding for word 2288
# No w2v embedding for word 117.9
# No w2v embedding for word 2130
# No w2v embedding for word 109.4
# No w2v embedding for word 2173
# No w2v embedding for word 1803
# No w2v embedding for word 120.5
# No w2v embedding for word 1791
# No w2v embedding for word 1820
# No w2v embedding for word 98.4
# No w2v embedding for word 1909
# No w2v embedding for word 1958
# No w2v embedding for word 97.5
# No w2v embedding for word 2103
# No w2v embedding for word 2091
# No w2v embedding for word 100.6
# No w2v embedding for word 2158
# No w2v embedding for word 2183
# No w2v embedding for word 98.9
# No w2v embedding for word 1642
# No w2v embedding for word 2361
# No w2v embedding for word 69.5
# No w2v embedding for word 1912
# No w2v embedding for word 87.5
# No w2v embedding for word 1578
# No w2v embedding for word 2060
# No w2v embedding for word 76.6
# No w2v embedding for word 1381
# No w2v embedding for word 2778
# No w2v embedding for word 49.7
# No w2v embedding for word 501
# No w2v embedding for word 569
# No w2v embedding for word 257
# No w2v embedding for word 560
# No w2v embedding for word 487
# No w2v embedding for word 359
# No w2v embedding for word 258
# No w2v embedding for word 502
# No w2v embedding for word 374
# No w2v embedding for word 421
# No w2v embedding for word 344
# No w2v embedding for word 366
# No w2v embedding for word 426
# No w2v embedding for word 406
# No w2v embedding for word 309
# No w2v embedding for word 435
# No w2v embedding for word 388
# No w2v embedding for word 391
# No w2v embedding for word 356
# No w2v embedding for word 395
# No w2v embedding for word 297
# No w2v embedding for word 448
# No w2v embedding for word 593
# No w2v embedding for word 351
# No w2v embedding for word 483
# No w2v embedding for word 304
# No w2v embedding for word 586
# No w2v embedding for word 460
# No w2v embedding for word 15-1
# No w2v embedding for word 10-15
# No w2v embedding for word 17-16
# No w2v embedding for word .547
# No w2v embedding for word .537
# No w2v embedding for word .534
# No w2v embedding for word .467
# No w2v embedding for word .357
# No w2v embedding for word .569
# No w2v embedding for word .470
# No w2v embedding for word 25th
# No w2v embedding for word .462
# No w2v embedding for word .542
# No w2v embedding for word .515
# No w2v embedding for word palmeiro
# No w2v embedding for word 9-5
# No w2v embedding for word wickman
# No w2v embedding for word 6-5
# No w2v embedding for word sixth-inning
# No w2v embedding for word 5-3
# No w2v embedding for word 21-year-old
# No w2v embedding for word 9-3
# No w2v embedding for word candiotti
# No w2v embedding for word 8-9
# No w2v embedding for word five-hitter
# No w2v embedding for word savicevic
# No w2v embedding for word 83rd
# No w2v embedding for word kongsvinger
# No w2v embedding for word skeid
# No w2v embedding for word stabaek
# No w2v embedding for word stromsgodset
# No w2v embedding for word lillestrom
# No w2v embedding for word duisberg
# No w2v embedding for word ferrigato
# No w2v embedding for word museeuw
# No w2v embedding for word baldato
# No w2v embedding for word sciandri
# No w2v embedding for word 199
# No w2v embedding for word 203
# No w2v embedding for word gorre
# No w2v embedding for word taument
# No w2v embedding for word harelbeke
# No w2v embedding for word 7th
# No w2v embedding for word 20th
# No w2v embedding for word 11,500
# No w2v embedding for word 74th
# No w2v embedding for word endt
# No w2v embedding for word azharuddin
# No w2v embedding for word four-nation
# No w2v embedding for word 1996-08-26
# No w2v embedding for word f.w
# No w2v embedding for word hit-squad
# No w2v embedding for word boraine
# No w2v embedding for word p.w
# No w2v embedding for word apartheid-era
# No w2v embedding for word 1948
# No w2v embedding for word serb-held
# No w2v embedding for word matuzici
# No w2v embedding for word doboj
# No w2v embedding for word multi-ethnic
# No w2v embedding for word reintegration
# No w2v embedding for word ejup
# No w2v embedding for word serb-controlled
# No w2v embedding for word shatoi
# No w2v embedding for word shkirko
# No w2v embedding for word dkba
# No w2v embedding for word suvit
# No w2v embedding for word f-14
# No w2v embedding for word mummification
# No w2v embedding for word dahshour
# No w2v embedding for word abdul-karim
# No w2v embedding for word al-kabariti
# No w2v embedding for word kabariti
# No w2v embedding for word weizman
# No w2v embedding for word yedioth
# No w2v embedding for word ahronoth
# No w2v embedding for word shumer
# No w2v embedding for word zicot
# No w2v embedding for word eight-year-olds
# No w2v embedding for word +331
# No w2v embedding for word muzaffarabad
# No w2v embedding for word pakistan-ruled
# No w2v embedding for word garhi
# No w2v embedding for word habibullah
# No w2v embedding for word gulbuddin
# No w2v embedding for word hekmatyar
# No w2v embedding for word bogra
# No w2v embedding for word odnosum
# No w2v embedding for word collectivisation
# No w2v embedding for word borsuk
# No w2v embedding for word mironivka
# No w2v embedding for word herbicides
# No w2v embedding for word 260
# ...
# No w2v embedding for word 248
# No w2v embedding for word 5.4
# No w2v embedding for word griqualand
# No w2v embedding for word ealham
# No w2v embedding for word 10no
# No w2v embedding for word 9.75
# No w2v embedding for word 6.00
# No w2v embedding for word caddick
# No w2v embedding for word 47.4
# No w2v embedding for word 141
# No w2v embedding for word 195
# No w2v embedding for word shadab
# No w2v embedding for word ata-ur-rehman
# No w2v embedding for word cozma
# No w2v embedding for word 3000
# No w2v embedding for word jansher
# No w2v embedding for word 13-15
# No w2v embedding for word 7-15
# No w2v embedding for word 12-15
# No w2v embedding for word 15-4
# No w2v embedding for word 15-14
# No w2v embedding for word kneipp
# No w2v embedding for word 8-15
# No w2v embedding for word szymanski
# No w2v embedding for word wiesner
# No w2v embedding for word majoli
# No w2v embedding for word mariaan
# No w2v embedding for word swardt
# No w2v embedding for word boogert
# No w2v embedding for word radka
# No w2v embedding for word kschwendt
# No w2v embedding for word likhovtseva
# No w2v embedding for word 7-
# No w2v embedding for word langrova
# No w2v embedding for word whitlinger
# No w2v embedding for word 7-9
# No w2v embedding for word dopfer
# No w2v embedding for word sawamatsu
# No w2v embedding for word oremans
# No w2v embedding for word .526
# No w2v embedding for word .492
# No w2v embedding for word vanlandingham
# No w2v embedding for word eldred
# No w2v embedding for word left-field
# No w2v embedding for word 29th
# No w2v embedding for word 85th
# No w2v embedding for word korneev
# No w2v embedding for word hansma
# No w2v embedding for word 23rd
# No w2v embedding for word bugno
# No w2v embedding for word mapei
# No w2v embedding for word koerts
# No w2v embedding for word palmans
# No w2v embedding for word teutenberg
# No w2v embedding for word capiot
# No w2v embedding for word collstrop
# No w2v embedding for word neths
# No w2v embedding for word blijlevens
# No w2v embedding for word foreldorado
# No w2v embedding for word cofinec
# No w2v embedding for word sitanyi
# No w2v embedding for word forints
# No w2v embedding for word erdei
# No w2v embedding for word krpaco
# No w2v embedding for word 336.47
# No w2v embedding for word 290.00
# No w2v embedding for word 700
# No w2v embedding for word 171.00
# No w2v embedding for word 960.00
# No w2v embedding for word 2470.00
# No w2v embedding for word 3024.95
# No w2v embedding for word 637.50
# No w2v embedding for word 156.00
# No w2v embedding for word 6000
# No w2v embedding for word 900.00
# No w2v embedding for word 785.00
# No w2v embedding for word 6700.00
# No w2v embedding for word 1915.00
# No w2v embedding for word worldcom
# No w2v embedding for word 312
# No w2v embedding for word faulding
# No w2v embedding for word purepac
# No w2v embedding for word 36-year-old
# No w2v embedding for word nuour
# No w2v embedding for word marial
# No w2v embedding for word mapourdit
# No w2v embedding for word tikhomirov
# No w2v embedding for word guldimann
# No w2v embedding for word 20-month-old
# No w2v embedding for word kwasniewski
# No w2v embedding for word kucan
# No w2v embedding for word iliescu
# No w2v embedding for word punr
# No w2v embedding for word ruutel
# No w2v embedding for word 101-member
# No w2v embedding for word 101
# No w2v embedding for word 273
# No w2v embedding for word markvart
# No w2v embedding for word xhelili
# No w2v embedding for word gajdos
# No w2v embedding for word quarracino
# No w2v embedding for word 232
# No w2v embedding for word hurte
# No w2v embedding for word zylstra
# No w2v embedding for word jetsi
# No w2v embedding for word hendrika
# No w2v embedding for word coers
# No w2v embedding for word schutte
# No w2v embedding for word huizinga
# No w2v embedding for word 582
# No w2v embedding for word 834405
# No w2v embedding for word banespa
# No w2v embedding for word bamerindus
# No w2v embedding for word lanusse
# No w2v embedding for word 1973
# No w2v embedding for word 1935
# No w2v embedding for word +6221
# No w2v embedding for word 384-6364
# No w2v embedding for word 10-year-old
# No w2v embedding for word muratovic
# No w2v embedding for word ciller
# No w2v embedding for word fulcheri
# No w2v embedding for word 4,200
# No w2v embedding for word 5.06
# No w2v embedding for word .02
# No w2v embedding for word .01
# No w2v embedding for word .10
# No w2v embedding for word 5.05
# No w2v embedding for word 312-408-8720
# No w2v embedding for word vmig-1
# No w2v embedding for word vmig
# No w2v embedding for word 08/28/96
# No w2v embedding for word 08/26/96
# No w2v embedding for word whistle-stop
# No w2v embedding for word millfeeds
# No w2v embedding for word millfeed
# No w2v embedding for word 140
# No w2v embedding for word 1.0
# No w2v embedding for word 8.32
# No w2v embedding for word pudvah
# No w2v embedding for word stagnates
# No w2v embedding for word 500,000
# No w2v embedding for word 2.4
# No w2v embedding for word essilor
# No w2v embedding for word abated
# No w2v embedding for word rifkind
# No w2v embedding for word rohrabacher
# No w2v embedding for word amrollah
# No w2v embedding for word 1.38
# No w2v embedding for word multi-party
# No w2v embedding for word khadga
# No w2v embedding for word three-party
# No w2v embedding for word 12,900-13,100
# No w2v embedding for word soyoil
# No w2v embedding for word soymeal
# No w2v embedding for word 12,600-12,750
# No w2v embedding for word 12,700-12,800
# No w2v embedding for word 12,750-12,900
# No w2v embedding for word 9,800
# No w2v embedding for word 8,800
# No w2v embedding for word m2
# No w2v embedding for word 8.2
# No w2v embedding for word 456.8
# No w2v embedding for word 439.9
# No w2v embedding for word helibor
# No w2v embedding for word 3.40
# No w2v embedding for word 3.34
# No w2v embedding for word 3.73
# No w2v embedding for word 3.70
# No w2v embedding for word a310
# No w2v embedding for word dtb-bund-future
# No w2v embedding for word dbrs
# No w2v embedding for word pfd-1
# No w2v embedding for word transkaryotic
# No w2v embedding for word emnid
# No w2v embedding for word 11.0
# No w2v embedding for word allensbach
# No w2v embedding for word 32.8
# No w2v embedding for word 13.0
# No w2v embedding for word 39.0
# No w2v embedding for word 40.0
# No w2v embedding for word 37.4
# No w2v embedding for word 7.3
# No w2v embedding for word 12.3
# No w2v embedding for word 43.0
# No w2v embedding for word 6.3
# No w2v embedding for word 4.30
# No w2v embedding for word 0330
# No w2v embedding for word mentmore
# No w2v embedding for word peiris
# No w2v embedding for word 14,000
# No w2v embedding for word sbpus
# No w2v embedding for word o-157
# No w2v embedding for word 8.9
# No w2v embedding for word 0.2
# No w2v embedding for word 3432
# No w2v embedding for word 6179
# No w2v embedding for word 0.05
# No w2v embedding for word sheu
# No w2v embedding for word 1996-08-28
# No w2v embedding for word 2.20
# No w2v embedding for word coceres
# No w2v embedding for word canonica
# No w2v embedding for word hedblom
# No w2v embedding for word sellberg
# No w2v embedding for word haeggman
# No w2v embedding for word 1:04.541
# No w2v embedding for word heeswijk
# No w2v embedding for word zanoli
# No w2v embedding for word citterio
# No w2v embedding for word ozers
# No w2v embedding for word 8:22:00
# No w2v embedding for word 4:13.353
# No w2v embedding for word szonn
# No w2v embedding for word collinelli
# No w2v embedding for word sandstod
# No w2v embedding for word friedick
# No w2v embedding for word time-trial
# No w2v embedding for word lausberg
# No w2v embedding for word thuet
# No w2v embedding for word dimitrios
# No w2v embedding for word georgalis
# No w2v embedding for word neiwand
# No w2v embedding for word hubner
# No w2v embedding for word 4,000
# No w2v embedding for word 13.353
# No w2v embedding for word 4:19.699
# No w2v embedding for word 4:17.696
# No w2v embedding for word obree
# No w2v embedding for word chester-le-street
# No w2v embedding for word 21-day
# No w2v embedding for word gatting
# No w2v embedding for word 1977
# No w2v embedding for word 244
# No w2v embedding for word neagle
# No w2v embedding for word mehrtens
# No w2v embedding for word herschelle
# No w2v embedding for word woolmer
# No w2v embedding for word 71-57
# No w2v embedding for word eyles
# No w2v embedding for word 15-13
# No w2v embedding for word tikva
# No w2v embedding for word she'an
# No w2v embedding for word 6-8
# No w2v embedding for word .522
# No w2v embedding for word fourth-seeded
# No w2v embedding for word 56th
# No w2v embedding for word jongsma
# No w2v embedding for word milinko
# No w2v embedding for word gabrich
# No w2v embedding for word cremonese
# No w2v embedding for word zickler
# No w2v embedding for word rizzitelli
# No w2v embedding for word feldhoff
# No w2v embedding for word 27,000
# No w2v embedding for word marc-vivien
# No w2v embedding for word guivarch
# No w2v embedding for word ferhaoui
# No w2v embedding for word vairelles
# No w2v embedding for word vierklau
# No w2v embedding for word 71st
# No w2v embedding for word 4x100
# No w2v embedding for word sanath
# No w2v embedding for word 226-5
# No w2v embedding for word romesh
# No w2v embedding for word kaluwitharana
# No w2v embedding for word man-of-the-match
# No w2v embedding for word aravinda
# No w2v embedding for word dharmasena
# No w2v embedding for word srinath
# No w2v embedding for word 226
# No w2v embedding for word mongia
# No w2v embedding for word pushpakumara
# No w2v embedding for word asanka
# No w2v embedding for word gurusinha
# No w2v embedding for word hashan
# No w2v embedding for word tillekeratne
# No w2v embedding for word mahanama
# No w2v embedding for word chaminda
# No w2v embedding for word muthiah
# No w2v embedding for word 1,100
# No w2v embedding for word morinville
# No w2v embedding for word berlex
# No w2v embedding for word avonex
# No w2v embedding for word betaseron
# No w2v embedding for word interferon
# No w2v embedding for word 212-859-1646
# No w2v embedding for word harleysville
# No w2v embedding for word 1965
# No w2v embedding for word 1952
# No w2v embedding for word 7717
# No w2v embedding for word bedie
# No w2v embedding for word foindu
# No w2v embedding for word overran
# No w2v embedding for word chiluba
# No w2v embedding for word mushota
# No w2v embedding for word shimaponda
# No w2v embedding for word guinean
# No w2v embedding for word 150,000
# No w2v embedding for word topolcany
# No w2v embedding for word kotlarska
# No w2v embedding for word 4.38
# No w2v embedding for word mokhoff
# No w2v embedding for word 0.300
# No w2v embedding for word nagyatad
# No w2v embedding for word srbska
# No w2v embedding for word gov't
# No w2v embedding for word 11.16
# No w2v embedding for word cvrd
# No w2v embedding for word 1996-08-29
# No w2v embedding for word 3.98
# No w2v embedding for word 90m
# No w2v embedding for word 1930s
# No w2v embedding for word 20.19
# No w2v embedding for word mosier
# No w2v embedding for word amoco
# No w2v embedding for word shabwa
# No w2v embedding for word buyoya
# No w2v embedding for word eksportfinans
# No w2v embedding for word suedwest
# No w2v embedding for word 97.82
# No w2v embedding for word palkhivala
# No w2v embedding for word 1994/95
# No w2v embedding for word wsrl
# No w2v embedding for word welspun
# No w2v embedding for word rameswaram
# No w2v embedding for word arulanandam
# No w2v embedding for word adelt
# No w2v embedding for word miltiadis
# No w2v embedding for word alexandroupolis
# No w2v embedding for word 600
# No w2v embedding for word drachmas
# No w2v embedding for word 2,563.16
# No w2v embedding for word 4.32
# No w2v embedding for word 108.40
# No w2v embedding for word 9002
# No w2v embedding for word akbel
# No w2v embedding for word aa2
# No w2v embedding for word 0.69
# No w2v embedding for word chiate
# No w2v embedding for word equitas
# No w2v embedding for word 1100
# No w2v embedding for word reppas
# No w2v embedding for word 1.09
# No w2v embedding for word cavorting
# No w2v embedding for word ducruet
# No w2v embedding for word houteman
# No w2v embedding for word bunol
# No w2v embedding for word 1945
# No w2v embedding for word georgiopoulos
# No w2v embedding for word 28.9
# No w2v embedding for word swebus
# No w2v embedding for word newcrest
# No w2v embedding for word bushland
# No w2v embedding for word shanghai-ek
# No w2v embedding for word ieng
# No w2v embedding for word mouly
# No w2v embedding for word takemura
# No w2v embedding for word hatoyama
# No w2v embedding for word stromme
# No w2v embedding for word 430
# No w2v embedding for word 47.5
# No w2v embedding for word 3,684
# No w2v embedding for word 7,011
# No w2v embedding for word dahman
# No w2v embedding for word qidra
# No w2v embedding for word banisadr
# No w2v embedding for word aaxis
# No w2v embedding for word 146
# No w2v embedding for word tacis
# No w2v embedding for word creutzfeldt-jakob
# No w2v embedding for word lebouc
# No w2v embedding for word 19.6
# No w2v embedding for word ekimov
# No w2v embedding for word breukink
# No w2v embedding for word voskamp
# No w2v embedding for word lietti
# No w2v embedding for word mg-technogym
# No w2v embedding for word overs-a-side
# No w2v embedding for word 225-5
# No w2v embedding for word 46.4
# No w2v embedding for word ballanger
# No w2v embedding for word dubnicoff
# No w2v embedding for word 225
# No w2v embedding for word 10-1-36-2
# No w2v embedding for word long-on
# No w2v embedding for word w-7
# No w2v embedding for word 10-0-52-0
# No w2v embedding for word 1996-08-30
# No w2v embedding for word grobbelaar
# No w2v embedding for word zifa
# No w2v embedding for word 69-60
# No w2v embedding for word 9-15
# No w2v embedding for word wengert
# No w2v embedding for word hentgen
# No w2v embedding for word hershiser
# No w2v embedding for word much-delayed
# No w2v embedding for word 94.26
# No w2v embedding for word 96.83
# No w2v embedding for word 3,894.00
# No w2v embedding for word ikimi
# No w2v embedding for word zvornik
# No w2v embedding for word kornblum
# No w2v embedding for word 2,901.48
# No w2v embedding for word roubles
# No w2v embedding for word filipovic
# No w2v embedding for word ocei
# No w2v embedding for word piotti
# No w2v embedding for word cetes
# No w2v embedding for word pessina
# No w2v embedding for word landless
# No w2v embedding for word skhirat
# No w2v embedding for word 200-an-hour
# No w2v embedding for word a-rated
# No w2v embedding for word +0.05
# No w2v embedding for word 4.90
# No w2v embedding for word dystrophin
# No w2v embedding for word oilseed
# No w2v embedding for word 212.25
# No w2v embedding for word 204.74
# No w2v embedding for word 15-30
# No w2v embedding for word 1,700
# No w2v embedding for word help-wanted
# No w2v embedding for word feugill
# No w2v embedding for word 2.7975
# No w2v embedding for word 117.00
# No w2v embedding for word 234,324
# No w2v embedding for word ecus
# No w2v embedding for word 1,800
# No w2v embedding for word vavuniya
# No w2v embedding for word vicorp
# No w2v embedding for word sabourin
# No w2v embedding for word 0.056
# No w2v embedding for word modem-chip
# No w2v embedding for word pmc-sierra
# No w2v embedding for word housecall
# No w2v embedding for word 10,650,407
# No w2v embedding for word 14,775,000
# No w2v embedding for word 2p
# No w2v embedding for word 715
# No w2v embedding for word 0900
# No w2v embedding for word 55,000-b
# No w2v embedding for word re-nomination
# No w2v embedding for word microfilm
# No w2v embedding for word pulpex
# No w2v embedding for word amsterdam-rotterdam-antwerp
# No w2v embedding for word 425
# No w2v embedding for word naphtha
# No w2v embedding for word 50-75
# No w2v embedding for word spitzbergen
# No w2v embedding for word galeforce
# No w2v embedding for word laasonen
# No w2v embedding for word kekkila
# No w2v embedding for word 9.5
# No w2v embedding for word zealands
# No w2v embedding for word 11.38
# No w2v embedding for word loxley
# No w2v embedding for word 332.66
# No w2v embedding for word yr-ago
# No w2v embedding for word +0.1
# No w2v embedding for word 119.3
# No w2v embedding for word +3.6
# No w2v embedding for word +0,2
# No w2v embedding for word 119.6
# No w2v embedding for word m4
# No w2v embedding for word trln
# No w2v embedding for word lenzing
# No w2v embedding for word widness
# No w2v embedding for word perelstein
# No w2v embedding for word samokhalova
# No w2v embedding for word goulnara
# No w2v embedding for word fatkoullina
# No w2v embedding for word haringa
# No w2v embedding for word kombouare

# %% [markdown]
# 🤔 Как происходит инициализация эмбеддингов для токенов, отсутствующих в модели word2vec?

# %% [markdown]
# Для этих токенов эмбеддинги останутся такими же, как и при инициализации слоя, то есть случайными.

# %% [markdown]
# ### Обучение и инференс (10 баллов)

# %%
ner_model.to(device)
print(ner_model)
# Out:
# TokenClassificationModel(
#   (embedding): Embedding(10946, 25)
#   (rnn): LSTM(25, 64, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=128, out_features=9, bias=True)
#   (loss_fn): CrossEntropyLoss()
# )

# %%
optimizer = ner_model.configure_optimizers()

# %%
for epoch in range(N_EPOCHS):
    ner_model.train()
    train_losses = []
    val_losses = []
    for i, batch in tqdm(enumerate(train_dl)):
        loss = ner_model.training_step(batch)
        train_losses.append(loss.detach().cpu().numpy())
        # YOUR_CODE_HERE
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    ner_model.eval()
    with torch.no_grad():
        for i, batch in tqdm(enumerate(val_dl)):
            loss = ner_model.validation_step(batch)
            val_losses.append(loss.cpu().numpy())
    train_loss = sum(train_losses) / len(train_losses)
    val_loss = sum(val_losses) / len(val_losses)

    print(f"{epoch = }: {train_loss = }, {val_loss = }")
    savepath = f"ner_model_{epoch}ep.bin"
    torch.save(ner_model.state_dict(), savepath)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 0: train_loss = 0.31044471864684026, val_loss = 0.2037384451010867
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 1: train_loss = 0.17339548986226933, val_loss = 0.1831453109032237
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 2: train_loss = 0.1413540390992626, val_loss = 0.17859812233912045
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 3: train_loss = 0.11917895546229662, val_loss = 0.16355446000941845
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 4: train_loss = 0.10563252775893803, val_loss = 0.16432131105616196
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 5: train_loss = 0.09461008401371217, val_loss = 0.16655703952567943
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 6: train_loss = 0.0887552311469998, val_loss = 0.16799152396389913
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 7: train_loss = 0.08152268923700264, val_loss = 0.16918522464420319
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 8: train_loss = 0.07679586689113077, val_loss = 0.17381846451298413
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch = 9: train_loss = 0.07447622334139087, val_loss = 0.17013154780593764

# %%
def predict(model, test_data) -> List[List[Tuple[str, int, int]]]:
    with torch.no_grad():
        model.eval()
        predictions = []
        for batch in tqdm(test_data):
            input_ids = batch["input_ids"]
            mask = batch["mask"]
            lengths = mask.sum(-1)
            logits = model.forward(input_ids, mask)
            preds = logits.argmax(dim=-1)
            for sample_pred, length in zip(preds, lengths):
                sample_pred = sample_pred[:length]
                spans = []  # class, start, end
                start = -1
                cur_label = ""
                for i in range(len(sample_pred)):
                    pred_label = idx2label[sample_pred[i]]
                    prefix = ""
                    if pred_label != "O":
                        prefix, pred_label = pred_label.split("-")

                    if pred_label == "O":
                        if start != -1:
                            spans.append([cur_label, start, i - 1])
                            start = -1
                            cur_label = ""
                    elif pred_label == cur_label and prefix == "I":
                        pass
                    else:
                        if start != -1:
                            spans.append([cur_label, start, i - 1])
                        start = i
                        cur_label = pred_label
                else:
                    if start != -1:
                        spans.append([cur_label, start, i])
                predictions.append(spans)

        return predictions

# %%
predictions = predict(ner_model, test_dl)
for sample, pred in zip(test_data, predictions):
    text = " ".join(sample["tokens"])
    print("*" * 100)
    print(text)

    for tag, start, end in pred:
        print(tag, " ".join(sample["tokens"][start:end + 1]))
# Out:
#   0%|          | 0/108 [00:00<?, ?it/s]
# ****************************************************************************************************
# SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRISE DEFEAT .
# LOC JAPAN
# LOC CHINA
# ****************************************************************************************************
# Nadim Ladki
# PER Nadim
# ****************************************************************************************************
# AL-AIN , United Arab Emirates 1996-12-06
# LOC AL-AIN
# LOC United
# ****************************************************************************************************
# Japan began the defence of their Asian Cup title with a lucky 2-1 win against Syria in a Group C championship match on Friday .
# LOC Japan
# MISC Asian Cup
# LOC Syria
# ****************************************************************************************************
# But China saw their luck desert them in the second match of the group , crashing to a surprise 2-0 defeat to newcomers Uzbekistan .
# LOC China
# ****************************************************************************************************
# China controlled most of the match and saw several chances missed until the 78th minute when Uzbek striker Igor Shkvyrin took advantage of a misdirected defensive header to lob the ball over the advancing Chinese keeper and into an empty net .
# LOC China
# PER Igor Shkvyrin
# MISC Chinese
# ****************************************************************************************************
# Oleg Shatskiku made sure of the win in injury time , hitting an unstoppable left foot shot from just outside the area .
# ****************************************************************************************************
# The former Soviet republic was playing in an Asian Cup finals tie for the first time .
# LOC Soviet republic
# MISC Asian Cup
# ****************************************************************************************************
# Despite winning the Asian Games title two years ago , Uzbekistan are in the finals as outsiders .
# MISC Asian
# ****************************************************************************************************
# Two goals from defensive errors in the last six minutes allowed Japan to come from behind and collect all three points from their opening meeting against Syria .
# LOC Japan
# LOC Syria
# ****************************************************************************************************
# Takuya Takagi scored the winner in the 88th minute , rising to head a Hiroshige Yanagimoto cross towards the Syrian goal which goalkeeper Salem Bitar appeared to have covered but then allowed to slip into the net .
# PER Takuya Takagi
# MISC Syrian
# PER Salem Bitar
# ****************************************************************************************************
# It was the second costly blunder by Syria in four minutes .
# LOC Syria
# ****************************************************************************************************
# Defender Hassan Abbas rose to intercept a long ball into the area in the 84th minute but only managed to divert it into the top corner of Bitar 's goal .
# PER Hassan Abbas
# PER 84th
# LOC Bitar
# ****************************************************************************************************
# Nader Jokhadar had given Syria the lead with a well-struck header in the seventh minute .
# PER Nader Jokhadar
# LOC Syria
# ****************************************************************************************************
# Japan then laid siege to the Syrian penalty area for most of the game but rarely breached the Syrian defence .
# LOC Japan
# LOC Syrian
# MISC Syrian
# ****************************************************************************************************
# Bitar pulled off fine saves whenever they did .
# ****************************************************************************************************
# Japan coach Shu Kamo said : ' ' The Syrian own goal proved lucky for us .
# LOC Japan
# PER Shu Kamo
# MISC Syrian
# ****************************************************************************************************
# The Syrians scored early and then played defensively and adopted long balls which made it hard for us . '
# MISC Syrians
# ****************************************************************************************************
# '
# ****************************************************************************************************
# Japan , co-hosts of the World Cup in 2002 and ranked 20th in the world by FIFA , are favourites to regain their title here .
# LOC Japan
# MISC World Cup
# ORG 20th
# ****************************************************************************************************
# Hosts UAE play Kuwait and South Korea take on Indonesia on Saturday in Group A matches .
# LOC UAE
# LOC Kuwait
# LOC South Korea
# LOC Indonesia
# ****************************************************************************************************
# All four teams are level with one point each from one game .
# ****************************************************************************************************
# RUGBY UNION - CUTTITTA BACK FOR ITALY AFTER A YEAR .
# ORG RUGBY UNION
# LOC ITALY
# ****************************************************************************************************
# ROME 1996-12-06
# LOC ROME
# ****************************************************************************************************
# Italy recalled Marcello Cuttitta
# LOC Italy
# ****************************************************************************************************
# on Friday for their friendly against Scotland at Murrayfield more than a year after the 30-year-old wing announced he was retiring following differences over selection .
# LOC Scotland
# ****************************************************************************************************
# Cuttitta , who trainer George Coste said was certain to play on Saturday week , was named in a 21-man squad lacking only two of the team beaten 54-21 by England at Twickenham last month .
# PER George Coste
# LOC England
# ****************************************************************************************************
# Stefano Bordon is out through illness and Coste said he had dropped back row Corrado Covi , who had been recalled for the England game after five years out of the national team .
# PER Stefano Bordon
# PER Corrado Covi
# LOC England
# ORG national team
# ****************************************************************************************************
# Cuttitta announced his retirement after the 1995 World Cup , where he took issue with being dropped from the Italy side that faced England in the pool stages .
# MISC World Cup
# LOC Italy
# LOC England
# ****************************************************************************************************
# Coste said he had approached the player two months ago about a comeback .
# ****************************************************************************************************
# " He ended the World Cup on the wrong note , " Coste said .
# MISC World Cup
# PER Coste
# ****************************************************************************************************
# " I thought it would be useful to have him back and he said he would be available .
# ****************************************************************************************************
# I think now is the right time for him to return . "
# ****************************************************************************************************
# Squad : Javier Pertile , Paolo Vaccari , Marcello Cuttitta , Ivan Francescato , Leandro Manteri , Diego Dominguez , Francesco Mazzariol , Alessandro Troncon , Orazio Arancio , Andrea Sgorlon , Massimo Giovanelli , Carlo Checchinato , Walter Cristofoletto , Franco Properzi Curti , Carlo Orlandi , Massimo Cuttitta , Giambatista Croci , Gianluca Guidi , Nicola Mazzucato , Alessandro Moscardi , Andrea Castellani .
# PER Javier Pertile
# PER Paolo Vaccari
# PER Marcello Cuttitta
# PER Ivan Francescato
# PER Leandro Manteri
# PER Diego Dominguez
# PER Francesco Mazzariol
# PER Alessandro Troncon
# PER Orazio Arancio
# PER Andrea Sgorlon
# PER Massimo Giovanelli
# PER Carlo Checchinato
# PER Walter Cristofoletto
# PER Franco Properzi Curti
# PER Carlo Orlandi
# PER Massimo Cuttitta
# PER Giambatista Croci
# PER Gianluca Guidi
# PER Nicola Mazzucato
# PER Alessandro Moscardi
# PER Andrea Castellani
# ****************************************************************************************************
# SOCCER - LATE GOALS GIVE JAPAN WIN OVER SYRIA .
# LOC JAPAN
# LOC SYRIA
# ****************************************************************************************************
# AL-AIN , United Arab Emirates 1996-12-06
# LOC AL-AIN
# LOC United
# ****************************************************************************************************
# Two goals in the last six minutes gave holders Japan an uninspiring 2-1 Asian Cup victory over Syria on Friday .
# LOC Japan
# MISC Asian Cup
# LOC Syria
# ****************************************************************************************************
# Takuya Takagi headed the winner in the 88th minute of the group C game after goalkeeper Salem Bitar spoiled a mistake-free display by allowing the ball to slip under his body .
# PER Takuya Takagi
# PER Salem Bitar spoiled
# ****************************************************************************************************
# It was the second Syrian defensive blunder in four minutes .
# MISC Syrian
# ****************************************************************************************************
# Defender Hassan Abbas rose to intercept a long ball into the area in the 84th minute but only managed to divert it into the top corner of Bitar 's goal .
# PER Hassan Abbas
# PER 84th
# LOC Bitar
# ****************************************************************************************************
# Syria had taken the lead from their first serious attack in the seventh minute .
# LOC Syria
# ****************************************************************************************************
# Nader Jokhadar headed a cross from the right by Ammar Awad into the top right corner of Kenichi Shimokawa 's goal .
# PER Kenichi Shimokawa
# ****************************************************************************************************
# Japan then laid siege to the Syrian penalty area and had a goal disallowed for offside in the 16th minute .
# LOC Japan
# MISC Syrian
# ****************************************************************************************************
# A minute later , Bitar produced a good double save , first from Kazuyoshi Miura 's header and then blocked a Takagi follow-up shot .
# PER Kazuyoshi
# ORG Miura
# ****************************************************************************************************
# Bitar saved well again from Miura in the 37th minute , parrying away his header from a corner .
# ****************************************************************************************************
# Japan started the second half brightly but Bitar denied them an equaliser when he dived to his right to save Naoki Soma 's low drive in the 53rd minute .
# LOC Japan
# PER Naoki Soma
# ****************************************************************************************************
# Japan : 19 - Kenichi Shimokawa , 2 - Hiroshige Yanagimoto , 3 - Naoki Soma , 4 - Masami Ihara , 5 - Norio Omura , 6 - Motohiro Yamaguchi , 8 - Masakiyo Maezono ( 7 - Yasuto Honda 71 ) , 9 - Takuya Takagi , 10 - Hiroshi Nanami , 11 - Kazuyoshi Miura , 15 - Hiroaki Morishima ( 14 - Masayuki Okano 75 ) .
# LOC Japan
# PER Kenichi Shimokawa
# PER Hiroshige Yanagimoto
# PER Naoki Soma
# PER Masami Ihara
# PER Norio Omura
# PER Motohiro Yamaguchi
# PER Masakiyo Maezono
# PER Honda
# PER Takuya Takagi
# PER Hiroshi Nanami
# PER Kazuyoshi Miura
# PER Hiroaki Morishima
# PER Masayuki Okano
# ****************************************************************************************************
# Syria : 24 - Salem Bitar , 3 - Bachar Srour ; 4 - Hassan Abbas , 5 - Tarek Jabban , 6 - Ammar Awad ( 9 - Louay Taleb 69 ) , 8 - Nihad al-Boushi , 10 - Mohammed Afash , 12 - Ali Dib , 13 - Abdul Latif Helou ( 17 - Ammar Rihawiy 46 ) , 14 - Khaled Zaher ; 16 - Nader Jokhadar .
# LOC Syria
# PER Salem
# PER Bachar Srour
# PER Hassan Abbas
# PER Tarek Jabban
# PER Ammar Awad
# PER Louay Taleb
# PER Nihad al-Boushi
# PER Mohammed Afash
# PER Ali Dib
# PER Abdul Latif Helou
# PER Ammar Rihawiy 46
# PER Khaled Zaher
# PER Nader Jokhadar
# ****************************************************************************************************
# FREESTYLE SKIING-WORLD CUP MOGUL RESULTS .
# MISC CUP
# ****************************************************************************************************
# TIGNES , France 1996-12-06
# LOC TIGNES
# LOC France
# ****************************************************************************************************
# Results of the World Cup
# MISC World Cup
# ****************************************************************************************************
# freestyle skiing moguls competition on Friday :
# ****************************************************************************************************
# Men
# ****************************************************************************************************
# 1. Jesper Ronnback ( Sweden ) 25.76 points
# PER Jesper Ronnback
# LOC Sweden
# ****************************************************************************************************
# 2. Andrei Ivanov ( Russia ) 24.88
# PER Andrei Ivanov
# LOC Russia
# ****************************************************************************************************
# 3. Ryan Johnson ( Canada ) 24.57
# PER Ryan Johnson
# LOC Canada
# ****************************************************************************************************
# 4. Jean-Luc Brassard ( Canada ) 24.40
# PER Jean-Luc Brassard
# LOC Canada
# ****************************************************************************************************
# 5. Korneilus Hole ( Norway ) 23.92
# PER Korneilus Hole
# LOC Norway
# ****************************************************************************************************
# 6. Jeremie Collomb-Patton ( France ) 23.87
# PER Jeremie Collomb-Patton
# LOC France
# ****************************************************************************************************
# 7. Jim Moran ( U.S. ) 23.25
# PER Jim Moran
# LOC U.S.
# ****************************************************************************************************
# 8. Dominick Gauthier ( Canada ) 22.73
# PER Dominick Gauthier
# LOC Canada
# ****************************************************************************************************
# 9. Johann Gregoire ( France ) 22.58
# PER Johann Gregoire
# LOC France
# ****************************************************************************************************
# 10. Troy Benson ( U.S. ) 22.56
# PER Troy Benson
# LOC U.S.
# ****************************************************************************************************
# Women
# ****************************************************************************************************
# 1. Tatjana Mittermayer ( Germany ) 24.32
# PER Tatjana Mittermayer
# LOC Germany
# ****************************************************************************************************
# 2. Candice Gilg ( France ) 24.31
# PER Candice Gilg
# LOC France
# ****************************************************************************************************
# 3. Minna Karhu ( Finland ) 24.05
# PER Minna Karhu
# LOC Finland
# ****************************************************************************************************
# 4. Tae Satoya ( Japan ) 23.75
# PER Tae Satoya
# LOC Japan
# ****************************************************************************************************
# 5. Ann Battellle ( U.S. ) 23.56
# PER Ann Battellle
# LOC U.S.
# ****************************************************************************************************
# 6. Donna Weinbrecht ( U.S. ) 22.48
# PER Donna Weinbrecht
# LOC U.S.
# ****************************************************************************************************
# 7. Liz McIntyre ( U.S. ) 22.00
# PER Liz McIntyre
# LOC U.S.
# ****************************************************************************************************
# 8. Elena Koroleva ( Russia ) 21.77
# PER Elena Koroleva
# LOC Russia
# ****************************************************************************************************
# 9. Ljudmila Dymchenko ( Russia ) 21.59
# PER Ljudmila Dymchenko
# LOC Russia
# ****************************************************************************************************
# 10. Katleen Allais ( France ) 21.58
# PER Katleen Allais
# LOC France
# ****************************************************************************************************
# SOCCER - ASIAN CUP GROUP C RESULTS .
# MISC ASIAN CUP
# ****************************************************************************************************
# AL-AIN , United Arab Emirates 1996-12-06
# LOC AL-AIN
# LOC United
# ****************************************************************************************************
# Results of Asian Cup group C matches played on Friday :
# MISC Asian Cup
# ****************************************************************************************************
# Japan 2 Syria 1 ( halftime 0-1 )
# ORG Japan
# ORG Syria
# ****************************************************************************************************
# Scorers :
# ****************************************************************************************************
# Japan - Hassan Abbas 84 own goal , Takuya Takagi 88 .
# LOC Japan
# PER Hassan Abbas
# LOC 88
# ****************************************************************************************************
# Syria - Nader Jokhadar 7
# LOC Syria
# ****************************************************************************************************
# Attendance : 10,000 .
# ****************************************************************************************************
# China 0 Uzbekistan 2 ( halftime 0-0 )
# LOC China
# ****************************************************************************************************
# Scorers : Shkvyrin Igor 78 , Shatskikh Oleg 90
# PER Shkvyrin Igor
# ****************************************************************************************************
# Attendence : 3,000
# ****************************************************************************************************
# Standings ( tabulate under played , won , drawn , lost , goals
# ****************************************************************************************************
# for , goals against , points ) :
# ****************************************************************************************************
# Uzbekistan 1 1 0 0 2 0 3
# ORG Uzbekistan
# ****************************************************************************************************
# Japan 1 1 0 0 2 1 3
# ORG Japan
# ****************************************************************************************************
# Syria 1 0 0 1 1 2 0
# LOC Syria
# ****************************************************************************************************
# China 1 0 0 1 0 2 0
# LOC China
# ****************************************************************************************************
# CRICKET - PAKISTAN V NEW ZEALAND ONE-DAY SCOREBOARD .
# LOC PAKISTAN
# LOC NEW ZEALAND
# ****************************************************************************************************
# [ CORRECTED 14:06 GMT ]
# MISC GMT
# ****************************************************************************************************
# SIALKOT , Pakistan 1996-12-06
# LOC SIALKOT
# LOC Pakistan
# ****************************************************************************************************
# Scoreboard in the second
# ****************************************************************************************************
# one-day cricket international between Pakistan and New Zealand
# LOC Pakistan
# LOC New Zealand
# ****************************************************************************************************
# on Friday :
# ****************************************************************************************************
# Pakistan
# LOC Pakistan
# ****************************************************************************************************
# Saeed Anwar run out 91 ( corrects from 90 )
# PER Saeed Anwar
# ****************************************************************************************************
# Zahoor Elahi b Cairns 86 ( corrects from 87 )
# PER Zahoor
# ORG Elahi
# ORG Cairns 86
# ****************************************************************************************************
# Ijaz Ahmad c Spearman b Vaughan 59
# PER Ijaz Ahmad
# PER Spearman
# PER Vaughan
# ****************************************************************************************************
# Inzamamul Haq st Germon b Astle 2
# ORG Inzamamul Haq
# ORG Germon
# ORG Astle
# ****************************************************************************************************
# Wasim Akram b Harris 4
# PER Wasim Akram
# PER Harris
# ****************************************************************************************************
# Shahid Afridi b Harris 2
# ORG Shahid Afridi
# ORG Harris
# ****************************************************************************************************
# Moin Khan c Astle b Harris 1
# PER Moin Khan
# PER Astle
# PER Harris
# ****************************************************************************************************
# Waqar Younis st Germon b Harris 0
# PER Waqar Younis
# ORG Germon
# PER Harris
# ****************************************************************************************************
# Saqlain Mushtaq b Harris 2
# PER Saqlain Mushtaq
# PER Harris
# ****************************************************************************************************
# Mushtaq Ahmad not out 5
# PER Mushtaq Ahmad
# ****************************************************************************************************
# Salim Malik not out 1
# PER Salim Malik
# ****************************************************************************************************
# Extras ( lb-8 nb-2 w-14 ) 24
# ****************************************************************************************************
# Total ( for 9 wickets in 47 overs ) 277
# ****************************************************************************************************
# Fall of wicket : 1-177 ( corrects from 1-178 ) 2-225 3-240 4-247 5-252 6-260 7-261 8-269 9-276
# ****************************************************************************************************
# Bowling : Doull 8-1-60-0 ( w-3 ) , Kennedy 3-0-24-0 ( w-7 nb-1 ) ,
# PER Doull 8-1-60-0
# PER Kennedy 3-0-24-0
# ****************************************************************************************************
# Cairns 8-1-35-1 ( w-2 ) , Vaughan 9-1-55-1 , Harris 10-0-42-5 ( w-1 ) ,
# ORG Cairns
# PER Vaughan
# PER Harris 10-0-42-5
# ****************************************************************************************************
# Astle 9-0-53-1 ( w-1 nb-1 )
# PER Astle 9-0-53-1
# LOC w-1
# ****************************************************************************************************
# New Zealand innings
# LOC New Zealand
# ****************************************************************************************************
# B. Young c Moin Khan b Waqar 5
# PER B. Young
# PER Moin Khan
# PER Waqar
# ****************************************************************************************************
# C. Spearman c Moin Khan b Wasim 0
# PER C. Spearman
# PER Moin Khan
# PER Wasim
# ****************************************************************************************************
# A. Parore c Ijaz Ahmad b Saqlain 37
# PER A. Parore
# PER Ijaz Ahmad
# PER Saqlain
# ****************************************************************************************************
# S. Fleming c and b Afridi 88
# PER S. Fleming
# ****************************************************************************************************
# C. Cairns b Saqlain 10
# PER C. Cairns
# PER Saqlain
# ****************************************************************************************************
# N. Astle c Ijaz Ahmad b Salim Malik 20
# PER Ijaz Ahmad
# PER Salim Malik
# ****************************************************************************************************
# C. Harris lbw b Wasim 22
# PER C. Harris
# PER Wasim
# ****************************************************************************************************
# L. Germon lbw b Afridi 2
# PER L. Germon
# PER Afridi
# ****************************************************************************************************
# J. Vaughan c Moin Khan b Wasim 13
# PER J. Vaughan
# PER Moin Khan
# PER Wasim
# ****************************************************************************************************
# S. Doull c subs ( M. Wasim ) b Waqar 1
# PER S. Doull
# PER subs
# PER M. Wasim
# PER Waqar
# ****************************************************************************************************
# R. Kennedy not out 7
# PER R. Kennedy
# ****************************************************************************************************
# Extras ( b-9 lb-3 w-12 nb-2 ) 26
# ****************************************************************************************************
# Total ( all out in 42.1 overs ) 231
# ****************************************************************************************************
# Fall of wickets : 1-3 2-7 3-125 4-146 5-170 6-190 7-195
# ****************************************************************************************************
# 8-213 9-216 .
# PER 8-213
# ****************************************************************************************************
# Bowling : Wasim Akram 8.1-0-43-3 ( 9w , 1nb ) , Waqar Younis
# PER Wasim Akram
# PER Waqar Younis
# ****************************************************************************************************
# 6-0-32-2 ( 2w , 1nb ) , Saqlain Mushtaq 8-0-54-2 , Mushtaq Ahmad
# PER Saqlain Mushtaq
# PER Mushtaq Ahmad
# ****************************************************************************************************
# 10-0-42-0 ( 1w ) , Shahid Afridi 7-0-40-2 , Salim Malik 2.5-0-8-1 ,
# PER 10-0-42-0
# PER Shahid Afridi 7-0-40-2
# PER Salim Malik 2.5-0-8-1
# ****************************************************************************************************
# Ijaz Ahmad 0.1-0-0-0 .
# PER Ijaz Ahmad
# ****************************************************************************************************
# Result : Pakistan won by 46 runs .
# LOC Pakistan
# ****************************************************************************************************
# Third one-day match : December 8 , in Karachi .
# LOC Karachi
# ****************************************************************************************************
# SOCCER - ENGLISH F.A. CUP SECOND ROUND RESULT .
# MISC ENGLISH
# MISC F.A. CUP
# ****************************************************************************************************
# LONDON 1996-12-06
# LOC LONDON
# ****************************************************************************************************
# Result of an English F.A. Challenge
# MISC English
# ****************************************************************************************************
# Cup second round match on Friday :
# MISC Cup
# ****************************************************************************************************
# Plymouth 4 Exeter 1
# ORG Plymouth
# ORG Exeter
# ****************************************************************************************************
# SOCCER - BLINKER BAN LIFTED .
# ****************************************************************************************************
# LONDON 1996-12-06
# LOC LONDON
# ****************************************************************************************************
# Dutch forward Reggie Blinker had his indefinite suspension lifted by FIFA on Friday and was set to make his Sheffield Wednesday comeback against Liverpool on Saturday .
# MISC Dutch
# PER Reggie Blinker
# ORG Sheffield
# ORG Liverpool
# ****************************************************************************************************
# Blinker missed his club 's last two games after FIFA slapped a worldwide ban on him for appearing to sign contracts for both Wednesday and Udinese while he was playing for Feyenoord .
# ORG Udinese
# ORG Feyenoord
# ****************************************************************************************************
# FIFA 's players ' status committee , meeting in Barcelona , decided that although the Udinese document was basically valid , it could not be legally protected .
# ORG status
# LOC Barcelona
# ORG Udinese
# ****************************************************************************************************
# The committee said the Italian club had violated regulations by failing to inform Feyenoord , with whom the player was under contract .
# MISC Italian
# ORG Feyenoord
# ****************************************************************************************************
# Blinker was fined 75,000 Swiss francs ( $ 57,600 ) for failing to inform the Engllsh club of his previous commitment to Udinese .
# MISC 75,000
# MISC Swiss
# ORG Engllsh
# ORG Udinese
# ****************************************************************************************************
# SOCCER - LEEDS ' BOWYER FINED FOR PART IN FAST-FOOD FRACAS .
# ORG LEEDS
# ORG BOWYER
# MISC FAST-FOOD
# ****************************************************************************************************
# LONDON 1996-12-06
# LOC LONDON
# ****************************************************************************************************
# Leeds ' England under-21 striker Lee Bowyer was fined 4,500 pounds ( $ 7,400 ) on Friday for hurling chairs at restaurant staff during a disturbance at a McDonald 's fast-food restaurant .
# LOC Leeds
# ORG England
# PER Lee Bowyer
# ****************************************************************************************************
# Bowyer , 19 , who was caught in the act by security cameras , pleaded guilty to a charge of affray at a court in London .
# LOC London
# ****************************************************************************************************
# He was fined and ordered to pay a total of 175 pounds to two members of staff injured in the fracas in an east London restaurant in October .
# LOC London
# ****************************************************************************************************
# Leeds had already fined Bowyer 4,000 pounds ( $ 6,600 ) and warned him a repeat of his criminal behaviour could cost him his place in the side .
# ORG Leeds
# ****************************************************************************************************
# Bowyer , who moved to the Yorkshire club in August for 3.5 million pounds ( $ 5.8 million ) , was expected to play against Middlesbrough on Saturday .
# ORG Yorkshire club
# ORG Middlesbrough
# ****************************************************************************************************
# BASKETBALL - EUROLEAGUE STANDINGS .
# ****************************************************************************************************
# LONDON 1996-12-06
# LOC LONDON
# ****************************************************************************************************
# Standings in the men 's EuroLeague
# ****************************************************************************************************
# basketball championship after Thursday 's matches ( tabulate under
# ****************************************************************************************************
# played , won , lost , points ) :
# ****************************************************************************************************
# Group A
# ****************************************************************************************************
# CSKA Moscow ( Russia 9 6 3 15
# ORG CSKA Moscow
# LOC Russia
# ****************************************************************************************************
# Stefanel Milan ( Italy ) 9 6 3 15
# PER Stefanel Milan
# LOC Italy
# ****************************************************************************************************
# Maccabi Tel Aviv ( Israel ) 9 5 4 14
# ORG Maccabi Tel Aviv
# LOC Israel
# ****************************************************************************************************
# Ulker Spor ( Turkey ) 9 4 5 13
# PER Ulker Spor
# LOC Turkey
# ****************************************************************************************************
# Limoges ( France ) 9 3 6 12
# PER Limoges
# LOC France
# ****************************************************************************************************
# Panionios ( Greece ) 9 3 6 12
# PER Panionios
# LOC Greece
# ****************************************************************************************************
# Group B
# ****************************************************************************************************
# Teamsystem Bologna ( Italy ) 9 7 2 16
# PER Teamsystem Bologna
# LOC Italy
# ****************************************************************************************************
# Olympiakos ( Greece ) 9 5 4 14
# ORG Olympiakos
# LOC Greece
# ****************************************************************************************************
# Cibona Zagreb ( Croatia ) 9 5 4 14
# ORG Cibona Zagreb
# LOC Croatia
# ****************************************************************************************************
# Alba Berlin ( Germany ) 9 5 4 14
# PER Alba Berlin
# LOC Germany
# ****************************************************************************************************
# Estudiantes Madrid ( Spain ) 9 5 4 14
# PER Estudiantes Madrid
# LOC Spain
# ****************************************************************************************************
# Charleroi ( Belgium ) 9 0 9 9
# ORG Charleroi
# LOC Belgium
# ****************************************************************************************************
# Group C
# ****************************************************************************************************
# Panathinaikos ( Greece ) 9 7 2 16
# PER Panathinaikos
# LOC Greece
# ****************************************************************************************************
# Ljubljana ( Slovenia ) 9 6 3 15
# LOC Ljubljana
# LOC Slovenia
# ****************************************************************************************************
# Villeurbanne ( France ) 9 6 3 15
# PER Villeurbanne
# LOC France
# ****************************************************************************************************
# Barcelona ( Spain ) 9 4 5 13
# ORG Barcelona
# LOC Spain
# ****************************************************************************************************
# Split ( Croatia ) 9 4 5 13
# LOC Croatia
# ****************************************************************************************************
# Bayer Leverkusen ( Germany ) 9 0 9 9
# ORG Bayer Leverkusen
# LOC Germany
# ****************************************************************************************************
# Group D
# ****************************************************************************************************
# Efes Pilsen ( Turkey ) 9 7 2 16
# PER Efes Pilsen
# LOC Turkey
# ****************************************************************************************************
# Pau-Orthez ( France ) 9 5 4 14
# LOC France
# ****************************************************************************************************
# Partizan Belgrade ( Yugoslavia ) 9 5 4 14
# ORG Partizan Belgrade
# LOC Yugoslavia
# ****************************************************************************************************
# Kinder Bologna ( Italy ) 9 4 5 13
# PER Kinder Bologna
# LOC Italy
# ****************************************************************************************************
# Sevilla ( Spain ) 9 4 5 13
# PER Sevilla
# LOC Spain
# ****************************************************************************************************
# Dynamo Moscow ( Russia ) 9 2 7 11
# ORG Dynamo
# LOC Moscow
# LOC Russia
# ****************************************************************************************************
# RUGBY UNION - LITTLE TO MISS CAMPESE FAREWELL .
# ORG RUGBY UNION
# MISC MISS
# ****************************************************************************************************
# Robert Kitson
# PER Robert Kitson
# ****************************************************************************************************
# LONDON 1996-12-06
# LOC LONDON
# ****************************************************************************************************
# Centre Jason Little will miss Australia 's end-of-tour fixture against the Barbarians at Twickenham on Saturday .
# PER Jason Little
# LOC Australia
# LOC Twickenham
# ****************************************************************************************************
# Little has opted not to risk aggravating the knee injury which ruled him out of a large chunk of the tour and is replaced by fellow Queenslander Daniel Herbert .
# MISC fellow
# PER Daniel Herbert
# ****************************************************************************************************
# Owen Finegan has recovered from the knocks he took in last weekend 's test against Wales and retains his place in the back-row ahead of Daniel Manu .
# PER Owen Finegan
# LOC Wales
# LOC retains
# PER Daniel Manu
# ****************************************************************************************************
# The Wallabies have their sights set on a 13th successive victory to end their European tour with a 100 percent record but also want to turn on the style and provide David Campese with a fitting send-off in his final match in Australian colours .
# MISC European
# PER David Campese
# MISC Australian
# ****************************************************************************************************
# The Wallabies currently have no plans to make any special presentation to the 34-year-old winger but a full house of 75,000 spectators will still gather in the hope of witnessing one last moment of magic .
# ****************************************************************************************************
# Campese will be up against a familiar foe in the shape of Barbarians captain Rob Andrew , the man who kicked Australia to defeat with a last-ditch drop-goal in the World Cup quarter-final in Cape Town .
# PER Rob Andrew
# LOC Australia
# MISC World Cup
# LOC Cape Town
# ****************************************************************************************************
# " Campo has a massive following in this country and has had the public with him ever since he first played here in 1984 , " said Andrew , also likely to be making his final Twickenham appearance .
# PER " Campo
# PER Andrew
# ****************************************************************************************************
# On tour , Australia have won all four tests against Italy , Scotland , Ireland and Wales , and scored 414 points at an average of almost 35 points a game .
# LOC tour
# LOC Australia
# LOC Italy
# LOC Scotland
# LOC Ireland
# LOC Wales
# ****************************************************************************************************
# League duties restricted the Barbarians ' selectorial options but they still boast 13 internationals including England full-back Tim Stimpson and recalled wing Tony Underwood , plus All Black forwards Ian Jones and Norm Hewitt .
# LOC England
# PER Tim Stimpson
# PER Tony Underwood
# PER Ian Jones
# PER Norm Hewitt
# ****************************************************************************************************
# Teams :
# ****************************************************************************************************
# Barbarians - 15 - Tim Stimpson ( England ) ; 14 - Nigel Walker ( Wales ) , 13 - Allan Bateman ( Wales ) , 12 - Gregor Townsend ( Scotland ) , 11 - Tony Underwood ( England ) ; 10 - Rob Andrew ( England ) , 9 - Rob Howley ( Wales ) ; 8 - Scott Quinnell ( Wales ) , 7 - Neil Back ( England ) , 6 - Dale McIntosh ( Pontypridd ) , 5 - Ian Jones ( New Zealand ) , 4 - Craig Quinnell ( Wales ) , 3 - Darren Garforth ( Leicester ) , 2 - Norm Hewitt ( New Zealand ) , 1 - Nick Popplewell ( Ireland ) .
# PER Tim Stimpson
# LOC England
# PER Nigel Walker
# LOC Wales
# PER 13
# PER Allan Bateman
# LOC Wales
# PER Gregor Townsend
# LOC Scotland
# PER 11
# PER Tony Underwood
# LOC England
# PER Rob Andrew
# LOC England
# PER Rob Howley
# LOC Wales
# PER Scott Quinnell
# LOC Wales
# PER 7
# PER Neil Back
# LOC England
# PER Dale McIntosh
# PER Ian Jones
# LOC New Zealand
# PER Craig Quinnell
# LOC Wales
# PER Darren Garforth
# LOC Leicester
# PER Norm Hewitt
# LOC New Zealand
# PER Nick Popplewell
# LOC Ireland
# ****************************************************************************************************
# Australia - 15 - Matthew Burke ; 14 - Joe Roff , 13 - Daniel Herbert , 12 - Tim Horan ( captain ) , 11 - David Campese ; 10 - Pat Howard , 9 - Sam Payne ; 8 - Michael Brial , 7 - David Wilson , 6 - Owen Finegan , 5 - David Giffin , 4 - Tim Gavin , 3 - Andrew Blades , 2 - Marco Caputo , 1 - Dan Crowley .
# LOC Australia
# PER Matthew Burke
# PER Joe Roff
# PER Daniel Herbert
# PER Tim Horan
# PER 11
# PER David Campese
# PER Pat Howard
# PER Sam Payne
# PER Michael Brial
# PER David Wilson
# PER Owen Finegan
# PER David Giffin
# PER Tim Gavin
# PER Andrew Blades
# PER Marco Caputo
# PER Dan Crowley
# ****************************************************************************************************
# GOLF - ZIMBABWE OPEN SECOND ROUND SCORES .
# LOC ZIMBABWE
# ****************************************************************************************************
# HARARE 1996-12-06
# LOC HARARE
# ****************************************************************************************************
# Leading second round scores in the Zimbabwe Open at the par-72 Chapman Golf Club on Friday ( South African unless stated ) : 132 Des Terblanche 65 67 133 Mark McNulty ( Zimbabwe ) 72 61 134 Steve van Vuuren 65 69 136 Nick Price ( Zimbabwe ) 68 68 , Justin Hobday 71 65 ,
# LOC Zimbabwe
# MISC Open
# MISC Chapman Golf
# MISC South African
# PER Mark McNulty
# LOC Zimbabwe
# PER Steve van Vuuren
# PER Nick Price
# LOC Zimbabwe
# PER Justin Hobday
# ****************************************************************************************************
# Andrew Pitts ( U.S. ) 69 67 138 Mark Cayeux ( Zimbabwe ) 69 69 , Mark Murless 71 67 139 Hennie Swart 75 64 , Andrew Park 72 67 140 Schalk van der Merwe ( Namibia ) 67 73 , Desvonde
# PER Andrew Pitts
# LOC U.S.
# PER Mark Cayeux
# LOC Zimbabwe
# PER Mark Murless
# PER Swart 75
# PER Andrew Park
# PER van der Merwe
# LOC Namibia
# ****************************************************************************************************
# Botes 72 68 , Greg Reid 72 68 , Clinton Whitelaw 70
# PER Greg Reid
# PER Clinton Whitelaw
# ****************************************************************************************************
# 70 , Brett Liddle 75 65 , Hugh Baiocchi 73 67 141 Adilson da Silva ( Brazil ) 72 69 , Sammy Daniels 73
# PER Brett Liddle
# PER Hugh Baiocchi
# PER da Silva
# LOC Brazil
# PER Sammy Daniels
# ****************************************************************************************************
# 68 , Trevor Dodds ( Namibia ) 72 69 142 Don Robertson ( U.S. ) 73 69 , Dion Fourie 69 73 ,
# PER Trevor Dodds
# LOC Namibia
# PER Don Robertson
# LOC U.S.
# PER Dion Fourie
# ****************************************************************************************************
# Steve Waltman 72 70 , Ian Dougan 73 69
# PER Steve Waltman
# PER Ian Dougan
# ****************************************************************************************************
# SOCCER - UNCAPPED PLAYERS CALLED TO FACE MACEDONIA .
# LOC MACEDONIA
# ****************************************************************************************************
# BUCHAREST 1996-12-06
# LOC BUCHAREST
# ****************************************************************************************************
# Romania trainer Anghel Iordanescu called up three uncapped players on Friday in his squad to face Macedonia next week in a World Cup qualifier .
# LOC Romania
# PER Anghel Iordanescu
# LOC Macedonia
# MISC World Cup
# ****************************************************************************************************
# Midfielder Valentin Stefan and striker Viorel Ion of Otelul Galati and defender Liviu Ciobotariu of National Bucharest are the newcomers for the European group eight clash in Macedonia on December 14 .
# PER Valentin Stefan
# PER Viorel Ion
# PER Otelul Galati
# PER Liviu Ciobotariu
# LOC Bucharest
# MISC European
# LOC Macedonia
# ****************************************************************************************************
# Iordanescu said he had picked them because of their good performances in the domestic championship in which National Bucharest are top and Otelul Galati third . "
# LOC Bucharest
# PER Otelul
# ORG Galati
# ****************************************************************************************************
# I think it 's fair to give them a chance , " he told reporters .
# ****************************************************************************************************
# League title-holders Steaua Bucharest , who finished bottom of their Champions ' League group in the European Cup , have only two players in the squad .
# ORG Steaua Bucharest
# MISC European Cup
# ****************************************************************************************************
# Attacking midfielder Adrian Ilie , who recently moved from Steaua to Turkish club Galatasaray , is ruled out after two yellow-card offences .
# PER Adrian Ilie
# ORG Steaua
# ORG Turkish
# ORG Galatasaray
# ****************************************************************************************************
# Squad :
# ****************************************************************************************************
# Goalkeepers - Bogdan Stelea , Florin Prunea .
# PER Bogdan Stelea
# PER Florin Prunea
# ****************************************************************************************************
# Defenders - Dan Petrescu , Daniel Prodan , Anton Dobos , Cornel Papura , Liviu Ciobotariu , Tibor Selymess , Iulian Filipescu .
# PER Dan Petrescu
# PER Daniel Prodan
# PER Anton Dobos
# PER Cornel Papura
# PER Liviu Ciobotariu
# PER Tibor Selymess
# LOC Iulian
# PER Filipescu
# ****************************************************************************************************
# Midfielders - Gheorghe Hagi , Gheorghe Popescu , Constantin Galca , Valentin Stefan , Basarab Panduru , Dorinel Munteanu , Ovidiu Stinga .
# PER Gheorghe Hagi
# PER Gheorghe Popescu
# PER Constantin Galca
# PER Valentin Stefan
# PER Basarab Panduru
# PER Dorinel Munteanu
# LOC Ovidiu
# PER Stinga
# ****************************************************************************************************
# Forwards - Ioan Vladoiu , Gheorghe Craioveanu , Ionel Danciulescu , Viorel Ion .
# PER Ioan Vladoiu
# PER Gheorghe Craioveanu
# PER Ionel Danciulescu
# LOC Viorel
# PER Ion
# ****************************************************************************************************
# REUTER
# PER REUTER
# ****************************************************************************************************
# SOCCER - BRAZILIAN CHAMPIONSHIP RESULTS .
# MISC BRAZILIAN
# ****************************************************************************************************
# RIO DE JANEIRO 1996-12-05
# LOC RIO DE JANEIRO
# ****************************************************************************************************
# Results of Brazilian
# MISC Brazilian
# ****************************************************************************************************
# soccer championship semifinal , first leg matches on Thursday .
# ****************************************************************************************************
# Goias 1 Gremio 3
# ORG Goias
# ORG Gremio
# ****************************************************************************************************
# Portuguesa 1 Atletico Mineiro 0
# ORG Portuguesa
# ORG Atletico Mineiro
# ****************************************************************************************************
# CRICKET - LARA ENDURES ANOTHER MISERABLE DAY .
# ****************************************************************************************************
# Robert Galvin
# PER Robert Galvin
# ****************************************************************************************************
# MELBOURNE 1996-12-06
# LOC MELBOURNE
# ****************************************************************************************************
# ...
# LOC NEW YORK
# ****************************************************************************************************
# Results of National Hockey
# MISC National Hockey
# ****************************************************************************************************
# League games on Friday ( home team in CAPS ) :
# ****************************************************************************************************
# NY RANGERS 6 Toronto 5
# ORG NY RANGERS
# ORG Toronto
# ****************************************************************************************************
# BUFFALO 1 Anaheim 1 ( OT )
# ORG BUFFALO
# ORG Anaheim
# LOC OT
# ****************************************************************************************************
# Pittsburgh 5 WASHINGTON 3
# ORG Pittsburgh
# ORG WASHINGTON
# ****************************************************************************************************
# Montreal 3 CHICAGO 1
# ORG Montreal
# ORG CHICAGO
# ****************************************************************************************************
# Philadelphia 6 DALLAS 3
# ORG Philadelphia
# ORG DALLAS
# ****************************************************************************************************
# St Louis 4 COLORADO 3
# ORG St Louis
# ORG COLORADO
# ****************************************************************************************************
# EDMONTON 5 Ottawa 2
# ORG EDMONTON
# ORG Ottawa
# ****************************************************************************************************
# NHL ICE HOCKEY - CANUCKS RW BURE SUSPENDED FOR ONE GAME .
# PER RW BURE
# ****************************************************************************************************
# NEW YORK 1996-12-06
# LOC NEW YORK
# ****************************************************************************************************
# Vancouver Canucks star right wing Pavel Bure was suspended for one game by the National Hockey League and fined $ 1,000 Friday for his hit on Buffalo Sabres defenceman Garry Galley on Wednesday .
# LOC Vancouver
# PER Pavel Bure
# MISC National Hockey League
# PER Garry Galley
# ****************************************************************************************************
# Bure received a double-minor penalty for high-sticking with 2:22 left in the first period of Wednesday 's 7-6 overtime win by Vancouver after colliding with Galley in Buffalo zone .
# LOC Vancouver
# LOC Buffalo
# ****************************************************************************************************
# Galley suffered a concussion and did not return to the game .
# ****************************************************************************************************
# " Mr Bure left his feet to deliver a forearm blow to Mr Galley as he was about to be checked legally by his opponent , " said NHL discipline chief Brian Burke in handing out the suspension .
# PER Mr Bure
# PER NHL discipline
# PER Brian Burke
# ****************************************************************************************************
# " Although it is clear from the videotape that Mr Bure 's actions were a reaction to the impending hit and there was no intent to injure his opponent , there can be no excuse for this type of conduct , " Burke said .
# PER Mr Bure
# PER Burke
# ****************************************************************************************************
# Bure , who is struggling with only nine goals and 12 assists in 26 games , will miss Saturday 's home game against Ottawa .
# ORG Ottawa
# ****************************************************************************************************
# BOXING - SCHULZ DEFEATS RIBALTA IN IBF HEAVYWEIGHT FIGHT .
# LOC IBF HEAVYWEIGHT
# ****************************************************************************************************
# VIENNA 1996-12-07
# LOC VIENNA
# ****************************************************************************************************
# German Axel Schulz outpointed Cuba 's Jose Ribalta in their International Boxing Federation non-title 10-round heavyweight fight on Saturday .
# MISC German
# PER outpointed Cuba
# PER Jose Ribalta
# PER non-title
# PER 10-round
# ****************************************************************************************************
# SOCCER - SPANISH FIRST DIVISION SUMMARY .
# MISC SPANISH
# ****************************************************************************************************
# MADRID 1996-12-07
# LOC MADRID
# ****************************************************************************************************
# Summary of Saturday 's Spanish first division match :
# MISC Spanish
# ****************************************************************************************************
# Real Madrid 2 ( Davor Suker 24 , Predrag Mijatovic 48 ) Barcelona 0 .
# ORG Real
# ORG Madrid
# PER Mijatovic
# ORG Barcelona
# ****************************************************************************************************
# Halftime 1-0 .
# ****************************************************************************************************
# Attendance 106,000 .
# ****************************************************************************************************
# SOCCER - BALKAN STRIKE FORCE WIN OLD FIRM GAME FOR REAL .
# LOC BALKAN
# ****************************************************************************************************
# MADRID 1996-12-07
# LOC MADRID
# ****************************************************************************************************
# Real Madrid 's Balkan strike force of Davor Suker and Predrag Mijatovic shot their side to a 2-0 win over Barcelona in Spain 's old firm game on Saturday .
# ORG Real Madrid
# LOC Balkan
# PER Suker
# ORG Predrag
# ORG Barcelona
# LOC Spain
# ****************************************************************************************************
# The result leaves Real on 38 points after 16 games , four ahead of Barcelona .
# ORG Barcelona
# ****************************************************************************************************
# With just one league match scheduled before the New Year break , Real are also assured of spending Christmas ahead of their arch-rivals .
# ****************************************************************************************************
# A mix-up in the Barcelona defence let Croatian international Suker in midway through the first half , and Montenegrin striker Mijatovic made it 2-0 after fine work by Clarence Seedorf just after the break .
# ORG Barcelona
# MISC Croatian
# PER Mijatovic
# PER Clarence Seedorf
# ****************************************************************************************************
# Barcelona fought back strongly but were twice denied by the woodwork on an unusually quiet night for Brazilian striker Ronaldo .
# ORG Barcelona
# MISC Brazilian
# PER Ronaldo
# ****************************************************************************************************
# SOCCER - PSV HIT VOLENDAM FOR SIX .
# ORG PSV
# ORG VOLENDAM
# ****************************************************************************************************
# AMSTERDAM 1996-12-07
# LOC AMSTERDAM
# ****************************************************************************************************
# Brazilian striker Marcelo and Yugoslav midfielder Zeljko Petrovic each scored twice as Dutch first division leaders PSV Eindhoven romped to a 6-0 win over Volendam on Saturday .
# MISC Brazilian
# PER Marcelo
# MISC Yugoslav
# PER Zeljko Petrovic
# MISC Dutch
# ORG PSV Eindhoven
# ORG Volendam
# ****************************************************************************************************
# Their other marksmen were Brazilian defender Vampeta and Belgian striker Luc Nilis , his 14th of the season .
# MISC Brazilian
# MISC Belgian
# PER Luc Nilis
# ****************************************************************************************************
# PSV , well on the way to their 14th league title , outgunned Volendam in every department of the game .
# ORG PSV
# ORG Volendam
# ****************************************************************************************************
# They boast a nine-point lead over Feyenoord , who have two games in hand , and are 16 points clear of champions Ajax Amsterdam , who have played 18 matches compared to PSV 's 19 .
# ORG Feyenoord
# ORG Ajax Amsterdam
# ORG PSV
# ****************************************************************************************************
# Ajax face AZ Alkmaar away on Sunday and Feyenoord , eliminated from the UEFA Cup after losing 4-2 on aggregate to Tenerife on Tuesday , travel to De Graafschap Doetinchem .
# ORG Ajax
# ORG AZ Alkmaar
# ORG Feyenoord
# MISC UEFA Cup
# MISC Graafschap
# ORG Doetinchem
# ****************************************************************************************************
# The Doetinchem side , dubbed " The Super Peasants " , are one of the surprise packages of the season .
# ORG Doetinchem
# MISC Peasants
# ****************************************************************************************************
# They are fourth in the table .
# ****************************************************************************************************
# SOCCER - SPANISH FIRST DIVISION RESULT / STANDINGS .
# MISC SPANISH
# ****************************************************************************************************
# MADRID 1996-12-07
# LOC MADRID
# ****************************************************************************************************
# Result of Saturday 's only Spanish
# MISC Spanish
# ****************************************************************************************************
# first division match :
# ****************************************************************************************************
# Real Madrid 2 Barcelona 0
# ORG Real Madrid
# ORG Barcelona
# ****************************************************************************************************
# Standings ( tabulate under games played , won , drawn , lost ,
# ****************************************************************************************************
# goals for , against , points ) :
# ****************************************************************************************************
# Real Madrid 16 11 5 0 32 12 38
# ORG Real Madrid
# ****************************************************************************************************
# Barcelona 16 10 4 2 46 21 34
# ORG Barcelona
# ****************************************************************************************************
# Deportivo Coruna 15 9 6 0 23 7 33
# ORG Deportivo Coruna
# ****************************************************************************************************
# Real Betis 15 8 5 2 28 13 29
# ORG Real Betis
# ****************************************************************************************************
# Atletico Madrid 15 8 3 4 26 17 27
# ORG Atletico Madrid
# ****************************************************************************************************
# Athletic Bilbao 15 7 4 4 28 22 25
# ORG Athletic Bilbao
# ****************************************************************************************************
# Real Sociedad 15 7 3 5 20 18 24
# ****************************************************************************************************
# Valladolid 15 7 3 5 19 18 24
# ORG Valladolid
# ****************************************************************************************************
# Racing Santander 15 5 7 3 15 15 22
# ****************************************************************************************************
# Rayo Vallecano 15 5 5 5 21 19 20
# ORG Rayo Vallecano
# ****************************************************************************************************
# Valencia 15 6 2 7 23 22 20
# ORG Valencia
# ****************************************************************************************************
# Celta Vigo 15 5 5 5 17 17 20
# ORG Celta Vigo
# ****************************************************************************************************
# Tenerife 15 5 4 6 23 17 19
# ORG Tenerife
# ****************************************************************************************************
# Espanyol 15 4 4 7 17 20 16
# ORG Espanyol
# ****************************************************************************************************
# Oviedo 15 4 4 7 17 21 16
# ORG Oviedo
# ****************************************************************************************************
# Sporting Gijon 15 4 4 7 15 22 16
# ORG Sporting Gijon
# ****************************************************************************************************
# Logrones 15 4 3 8 11 33 15
# ORG Logrones
# ****************************************************************************************************
# Zaragoza 15 2 8 5 18 23 14
# ORG Zaragoza
# ****************************************************************************************************
# Sevilla 15 4 2 9 13 20 14
# ORG Sevilla
# ****************************************************************************************************
# Compostela 15 3 4 8 13 28 13
# ORG Compostela
# ****************************************************************************************************
# Hercules 15 2 2 11 11 29 8
# ORG Hercules
# ****************************************************************************************************
# Extremadura 15 1 3 11 8 30 6
# ORG Extremadura
# ****************************************************************************************************
# SOCCER - ENGLISHMAN CHARLTON IS MADE AN HONORARY IRISHMAN .
# PER ENGLISHMAN
# PER CHARLTON
# ****************************************************************************************************
# DUBLIN 1996-12-07
# LOC DUBLIN
# ****************************************************************************************************
# Jack Charlton 's relationship with the people of Ireland was cemented on Saturday when the Englishman was officially declared one of their own .
# PER Jack Charlton
# LOC Ireland
# ****************************************************************************************************
# Charlton , 61 , and his wife , Peggy , became citizens of Ireland when they formally received Irish passports from deputy Prime Minister Dick Spring who said the honour had been made in recognition of Charlton 's achievements as the national soccer manager .
# PER Charlton
# PER 61
# LOC Ireland
# MISC Irish
# PER Dick Spring
# ORG Charlton
# ORG national soccer
# ****************************************************************************************************
# " The years I spent as manager of the Republic of Ireland were the best years of my life .
# LOC Republic
# LOC Ireland
# ****************************************************************************************************
# It all culminated in the fact that I now have lots of great , great friends in Ireland .
# LOC Ireland
# ****************************************************************************************************
# That is why this is so emotional a night for me , " Charlton said .
# PER Charlton
# ****************************************************************************************************
# " It was the joy that we all had over the period , that I shared with people that I grew to love , that I treasure most , " he added .
# ****************************************************************************************************
# Charlton managed Ireland for 93 matches , during which time they lost only 17 times in almost 10 years until he resigned in December 1995 .
# ORG Charlton
# LOC Ireland
# ****************************************************************************************************
# He guided Ireland to two successive World Cup finals tournaments and to the 1988 European championship finals in Germany , after the Irish beat a well-fancied England team 1-0 in their group qualifier .
# LOC Ireland
# MISC World Cup
# MISC European
# LOC Germany
# MISC Irish
# LOC England
# ****************************************************************************************************
# The lanky former Leeds United defender did not make his England debut until the age of 30 but eventually won 35 caps and was a key member of the 1966 World Cup winning team with his younger brother , Bobby .
# ORG Leeds
# ORG defender
# LOC England
# MISC 1966
# MISC World Cup
# PER Bobby

# %% [markdown]
# Используя библиотеку https://github.com/chakki-works/seqeval, рассчитайте метрики.
#
# Результаты SotA-решений вы найдете на странице https://paperswithcode.com/sota/named-entity-recognition-ner-on-conll-2003.

# %%
# YOUR_CODE_HERE
from seqeval.metrics import classification_report
from seqeval.scheme import IOB2

y_true = [example["labels"] for example in test_dl.dataset]
y_pred = []
for example, pred in zip(test_dl.dataset, predictions):
    tags = ["O" for _ in range(len(example["labels"]))]
    for tag, start, end in pred:
        tags[start] = f"B-{tag}"
        for i in range(start + 1, end + 1):
            tags[i] = f"I-{tag}"
    y_pred.append(tags)

report = classification_report(y_true, y_pred, scheme=IOB2)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          LOC       0.79      0.80      0.80      1668
#         MISC       0.67      0.57      0.62       702
#          ORG       0.69      0.59      0.63      1661
#          PER       0.77      0.69      0.73      1617
#
#    micro avg       0.75      0.68      0.71      5648
#    macro avg       0.73      0.66      0.69      5648
# weighted avg       0.74      0.68      0.71      5648

# %% [markdown]
# ### Дополнительное задание (не оценивается)

# %% [markdown]
# (Опционально) Попробуйте повысить метрики. Вот несколько идей:
#
# 1. Взять более тяжелые эмбеддинги.
# 2. На замораживать слой эмбеддингов.
# 3. Использовать MLP после RNN.
# 4. Умная инициализация весов, дропаут, продвинутый оптимизатор, скедулер и т. д.
